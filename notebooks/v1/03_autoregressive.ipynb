# %%
import pandas as pd

import matplotlib

import matplotlib.pyplot as plt

import scipy.stats

from pmdarima import auto_arima

from arch import arch_model

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error, mean_absolute_error

import statsmodels.tsa.stattools as sts

from statsmodels.tsa.seasonal import seasonal_decompose

import statsmodels.graphics.tsaplots as sgt

from statsmodels.tsa.arima.model import ARIMA

from  scipy.stats.distributions import chi2

from statsmodels.tsa.api import VAR

from statsmodels.tsa.stattools import grangercausalitytests

import numpy as np

import seaborn as sns

import itertools

import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('BD preprocesada II.csv',sep=',')

# Formatear columna Fecha como datetime

df['Fecha'] = pd.to_datetime(df['Fecha'])

df.head()
# Out:
#        Fecha       AUM FIC      Efectivo  Reserva Bancaria  \
# 0 2018-01-01  4.277819e+07  58512.003886      28754.777759
# 1 2018-01-02  4.346588e+07  58512.003886      28754.777759
# 2 2018-01-03  4.427526e+07  58512.003886      28754.777759
# 3 2018-01-04  4.457223e+07  58512.003886      28754.777759
# 4 2018-01-05  4.464074e+07  58512.003886      28754.777759
#
#    Del sector privado  Del sector público  Cuentas de ahorro         CDT 1/  \
# 0        35602.554628        10671.094981      170017.348229  160226.125352
# 1        35602.554628        10671.094981      170017.348229  160226.125352
# 2        35602.554628        10671.094981      170017.348229  160226.125352
# 3        35602.554628        10671.094981      170017.348229  160226.125352
# 4        35602.554628        10671.094981      170017.348229  160226.125352
#
#    Otros depósitos a la vista  Inflación anual %  ...  Tasa A 120 días  \
# 0                 5328.184972               3.68  ...         0.052668
# 1                 5328.184972               3.37  ...         0.052668
# 2                 5328.184972               3.37  ...         0.053122
# 3                 5328.184972               3.37  ...         0.050867
# 4                 5328.184972               3.37  ...         0.051841
#
#    Tasa Entre 121 y 179 días  Tasa A 180 días  Tasa Entre 181 y 359 días  \
# 0                   0.055417         0.052354                   0.058845
# 1                   0.055417         0.052354                   0.058845
# 2                   0.056538         0.054354                   0.059277
# 3                   0.054752         0.053794                   0.058336
# 4                   0.055389         0.054582                   0.056345
#
#    Tasa A 360 días  Tasa Superiores a 360 días  \
# 0         0.057049                    0.061108
# 1         0.057049                    0.061108
# 2         0.055647                    0.065069
# 3         0.056066                    0.066029
# 4         0.055165                    0.062512
#
#    Tasa Captaciones a través de CDT por red de oficinas  \
# 0                                           0.052959
# 1                                           0.052959
# 2                                           0.052840
# 3                                           0.052695
# 4                                           0.052718
#
#    Tasa Captaciones a través de CDT por tesorería  Valor hoy    VALOR
# 0                                        0.058457     286.55  2940.94
# 1                                        0.058457     286.55  2940.94
# 2                                        0.064005     286.55  2940.94
# 3                                        0.064102     286.55  2908.68
# 4                                        0.057780     286.55  2885.76
#
# [5 rows x 29 columns]

# %%
# Fecha como índice

df.set_index('Fecha',inplace=True)

df.head()
# Out:
#                  AUM FIC      Efectivo  Reserva Bancaria  Del sector privado  \
# Fecha
# 2018-01-01  4.277819e+07  58512.003886      28754.777759        35602.554628
# 2018-01-02  4.346588e+07  58512.003886      28754.777759        35602.554628
# 2018-01-03  4.427526e+07  58512.003886      28754.777759        35602.554628
# 2018-01-04  4.457223e+07  58512.003886      28754.777759        35602.554628
# 2018-01-05  4.464074e+07  58512.003886      28754.777759        35602.554628
#
#             Del sector público  Cuentas de ahorro         CDT 1/  \
# Fecha
# 2018-01-01        10671.094981      170017.348229  160226.125352
# 2018-01-02        10671.094981      170017.348229  160226.125352
# 2018-01-03        10671.094981      170017.348229  160226.125352
# 2018-01-04        10671.094981      170017.348229  160226.125352
# 2018-01-05        10671.094981      170017.348229  160226.125352
#
#             Otros depósitos a la vista  Inflación anual %  \
# Fecha
# 2018-01-01                 5328.184972               3.68
# 2018-01-02                 5328.184972               3.37
# 2018-01-03                 5328.184972               3.37
# 2018-01-04                 5328.184972               3.37
# 2018-01-05                 5328.184972               3.37
#
#             Tasa de intervención de política monetaria (%)  ...  \
# Fecha                                                       ...
# 2018-01-01                                            4.75  ...
# 2018-01-02                                            4.75  ...
# 2018-01-03                                            4.75  ...
# 2018-01-04                                            4.75  ...
# 2018-01-05                                            4.75  ...
#
#             Tasa A 120 días  Tasa Entre 121 y 179 días  Tasa A 180 días  \
# Fecha
# 2018-01-01         0.052668                   0.055417         0.052354
# 2018-01-02         0.052668                   0.055417         0.052354
# 2018-01-03         0.053122                   0.056538         0.054354
# 2018-01-04         0.050867                   0.054752         0.053794
# 2018-01-05         0.051841                   0.055389         0.054582
#
#             Tasa Entre 181 y 359 días  Tasa A 360 días  \
# Fecha
# 2018-01-01                   0.058845         0.057049
# 2018-01-02                   0.058845         0.057049
# 2018-01-03                   0.059277         0.055647
# 2018-01-04                   0.058336         0.056066
# 2018-01-05                   0.056345         0.055165
#
#             Tasa Superiores a 360 días  \
# Fecha
# 2018-01-01                    0.061108
# 2018-01-02                    0.061108
# 2018-01-03                    0.065069
# 2018-01-04                    0.066029
# 2018-01-05                    0.062512
#
#             Tasa Captaciones a través de CDT por red de oficinas  \
# Fecha
# 2018-01-01                                           0.052959
# 2018-01-02                                           0.052959
# 2018-01-03                                           0.052840
# 2018-01-04                                           0.052695
# 2018-01-05                                           0.052718
#
#             Tasa Captaciones a través de CDT por tesorería  Valor hoy    VALOR
# Fecha
# 2018-01-01                                        0.058457     286.55  2940.94
# 2018-01-02                                        0.058457     286.55  2940.94
# 2018-01-03                                        0.064005     286.55  2940.94
# 2018-01-04                                        0.064102     286.55  2908.68
# 2018-01-05                                        0.057780     286.55  2885.76
#
# [5 rows x 28 columns]

# %%
diferencia = df.index.to_series().diff().dt.total_seconds()

diferencia.value_counts()
# Out:
# Fecha
# 86400.0    2410
# 0.0          22
# Name: count, dtype: int64

# %%
df.drop_duplicates(keep='first',inplace=True,ignore_index=False)

# %%
df.shape
# Out:
# (2411, 28)

# %%
fig,axes = plt.subplots(nrows=9,ncols=3, figsize = (20,30))

for i,ax in enumerate(axes.flatten()):
    data = df[df.columns[i]]
    ax.plot(data,color='red', linewidth = 1)

    # Ajustes al gráfico

    ax.set_title(df.columns[i])


plt.tight_layout()

# %% [markdown]
# ## Relación variables

# %%
corr_s = df.corr(method='spearman')

plt.subplots(figsize = (20,10))

# sns.heatmap(corr_s,xticklabels= corr_s.columns.values , yticklabels= corr_s.columns.values ,  annot= True , vmax= 1, vmin= -1, cmap= sns.diverging_palette(220,10, as_cmap= True),center=0)

alpha = np.abs(corr_s)

# cmap = sns.color_palette("coolwarm", as_cmap=True)

sns.heatmap(corr_s, annot=True, fmt=".2f",
             linewidths=0.5, vmin=-1, vmax=1, center=0,
            cbar_kws={"shrink": 0.8}, alpha=alpha.values)

# Resaltar correlaciones altas y bajas con bordes gruesos
for i in range(len(corr_s)):
    for j in range(len(corr_s)):
        value = corr_s.iloc[i, j]
        if abs(value) > 0.5:  # Resaltar correlaciones altas (>0.7 o <-0.7)
            plt.gca().add_patch(plt.Rectangle((j, i), 1, 1, fill=False, edgecolor='black', lw=2))

plt.title("Mapa de Calor Coeficiente de Correlación (Spearman) entre variables", fontsize=20)

# plt.xticks(rotation=45)


plt.show()

# %%
serie = df[['AUM FIC','Efectivo']]

serie.head()
# Out:
#                  AUM FIC      Efectivo
# Fecha
# 2018-01-01  4.277819e+07  58512.003886
# 2018-01-02  4.346588e+07  58512.003886
# 2018-01-03  4.427526e+07  58512.003886
# 2018-01-04  4.457223e+07  58512.003886
# 2018-01-05  4.464074e+07  58512.003886

# %%
sts.adfuller(serie['AUM FIC'])
# Out:
# (-1.0837189758482664,
#  0.721520727915121,
#  15,
#  2395,
#  {'1%': -3.4330833288586047,
#   '5%': -2.8627475469019337,
#   '10%': -2.567412827916545},
#  68737.50075061287)

# %%
sts.adfuller(serie['Efectivo'])
# Out:
# (-0.7964296504874624,
#  0.8201685816844384,
#  21,
#  2389,
#  {'1%': -3.433090201041693,
#   '5%': -2.862750581542575,
#   '10%': -2.567414443618994},
#  35927.9056022749)

# %% [markdown]
# Volver la serie estacionaria con las diferencias

# %%
serie_dif = serie.diff().dropna()

serie_dif = serie_dif[(serie_dif != 0).all(axis=1)]

serie_dif
# Out:
#                  AUM FIC     Efectivo
# Fecha
# 2018-01-06   6734.988641 -1912.465334
# 2018-01-13   7047.624598 -1158.360789
# 2018-01-20   6779.730104 -1210.942647
# 2018-01-27   8954.972046  1139.615413
# 2018-02-03   6038.756100 -1013.654724
# ...                  ...          ...
# 2024-06-01  22557.398097  1160.292575
# 2024-06-08  21575.713932  -320.642989
# 2024-06-15  20545.053360   125.324028
# 2024-06-22  17301.417742  2068.283621
# 2024-06-29  24667.715961  2645.747965
#
# [339 rows x 2 columns]

# %%
# serie_dif = serie_dif.diff().dropna()

# serie_dif = serie_dif[(serie_dif != 0).all(axis=1)]

# serie_dif

# %%
lista = serie_dif.index

serie_filtrada = serie.loc[lista]

serie_filtrada
# Out:
#                  AUM FIC       Efectivo
# Fecha
# 2018-01-06  4.464748e+07   56599.538551
# 2018-01-13  4.472463e+07   55441.177763
# 2018-01-20  4.419130e+07   54230.235116
# 2018-01-27  4.425412e+07   55369.850529
# 2018-02-03  4.510664e+07   54356.195805
# ...                  ...            ...
# 2024-06-01  7.587088e+07  108830.824490
# 2024-06-08  7.707061e+07  108510.181501
# 2024-06-15  7.657252e+07  108635.505529
# 2024-06-22  7.708270e+07  110703.789150
# 2024-06-29  7.533655e+07  113349.537115
#
# [339 rows x 2 columns]

# %%
sts.adfuller(serie_dif['AUM FIC'])
# Out:
# (-12.158888556592519,
#  1.509623480231161e-22,
#  1,
#  337,
#  {'1%': -3.4499043309021955,
#   '5%': -2.870154885338925,
#   '10%': -2.5713597190254385},
#  8359.021801246883)

# %%
sts.adfuller(serie_dif['Efectivo'])
# Out:
# (-5.023479980657041,
#  1.9937072355934818e-05,
#  16,
#  322,
#  {'1%': -3.4508226600665037,
#   '5%': -2.870558121868621,
#   '10%': -2.571574731684734},
#  5148.559114267848)

# %%
def tsplot (y,lags = None, figsize = (18,7),style = 'bmh'):
    if not isinstance(y,pd.Series):
        y = pd.Series(y)

    with plt.style.context(style):
        fig = plt.figure(figsize=figsize)
        layout = (2,2)
        ts_ax = plt.subplot2grid(layout,(0,0),colspan=2)
        acf_ax = plt.subplot2grid(layout,(1,0))
        pacf_ax = plt.subplot2grid(layout,(1,1))    

        y.plot(ax=ts_ax)
        p_value = sts.adfuller(y)[1]
        ts_ax.set_title('Gráfico de análisis de Serie de Tiempo Dickey- Fuller: p={0:.5f}'.format(p_value))
        sgt.plot_acf(y,lags=lags, ax=acf_ax)
        sgt.plot_pacf(y,lags=lags,ax=pacf_ax)
        plt.tight_layout()
        plt.show()

# %%
tsplot(serie_dif['AUM FIC'],lags=45)

# %%
tsplot(serie_dif['Efectivo'],lags=40)

# %%
N      = len(serie_dif)
n_tr   = int(0.80 * N)
n_val  = int(0.10 * N)

train  = serie_dif.iloc[:n_tr]
val    = serie_dif.iloc[n_tr:n_tr + n_val]
test   = serie_dif.iloc[n_tr + n_val:]

print(f'Train: {len(train)} | Val: {len(val)} | Test: {len(test)}')

# %% [markdown]
# ## ARIMA

# %%
# Definir función de 

def LLR_test(mod_1,mod_2, DF= 1):

    L1 = mod_1.llf
    L2= mod_2.llf
    LR= (2*(L2-L1))
    p = chi2.sf(LR,DF).round(3)
    return p

# %% [markdown]
# Modelo ARIMA

# %%
# p=d=q = range(0,5)

# pdq = list(itertools.product(p, d, q))

# # Función para encontrar el mejor modelo ARIMA basado en AIC
# def find_best_arima_model(ts, pdq):
#     best_aic = np.inf
#     best_pdq = None
#     best_model = None

#     for param in pdq:
#         try:
#             model = ARIMA(train['AUM FIC'], order=param)
#             results = model.fit()
#             if results.aic < best_aic:
#                 best_aic = results.aic
#                 best_pdq = param
#                 best_model = results
#         except:
#             continue
    
#     return best_pdq, best_model

# best_pdq, best_model = find_best_arima_model(train['AUM FIC'], pdq)

# print(f'Mejor AIC: {best_model.aic}')
# print(f'Mejor orden (p, d, q): {best_pdq}')
# print(best_model.summary())

# %%
model_arima = ARIMA(train['AUM FIC'],order = (2,4,3))

results_arima = model_arima.fit(method='innovations_mle')

print(results_arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                AUM FIC   No. Observations:                  332
# Model:                 ARIMA(2, 4, 3)   Log Likelihood               -4443.613
# Date:                Thu, 28 Nov 2024   AIC                           8899.226
# Time:                        21:49:05   BIC                           8921.984
# Sample:                    01-06-2018   HQIC                          8908.306
#                          - 05-11-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5739      0.011   -144.168      0.000      -1.595      -1.553
# ar.L2         -0.6574      0.016    -39.982      0.000      -0.690      -0.625
# ma.L1         -0.9966      0.339     -2.942      0.003      -1.661      -0.333
# ma.L2         -0.9999      0.340     -2.940      0.003      -1.666      -0.333
# ma.L3          0.9967      0.015     66.984      0.000       0.968       1.026
# sigma2      2.806e+10   3.63e-11   7.73e+20      0.000    2.81e+10    2.81e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  17.29   Jarque-Bera (JB):             66835.20
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):             169.47   Skew:                             3.62
# Prob(H) (two-sided):                  0.00   Kurtosis:                        72.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.58e+36. Standard errors may be unstable.

# %%
start = len(train)

end = len(train) + len(test) - 1

rename = f'ARIMA(3,5,6) Predictions'

fcast_arima = results_arima.predict(start =start, end = end ,dynamic=False).rename(rename)

# %%
pred_arima = pd.DataFrame(fcast_arima,index=fcast_arima.index)

pred_arima = pred_arima.rename(columns={'ARIMA(3,5,6) Predictions': 'AUM FIC'})

pred_arima
# Out:
#                  AUM FIC
# 2024-05-18 -4.051748e+05
# 2024-05-25 -1.523554e+05
# 2024-06-01 -6.927203e+05
# 2024-06-08 -4.384398e+05
# 2024-06-15 -9.160886e+05
# 2024-06-22 -7.668110e+05
# 2024-06-29 -1.125847e+06

# %%
n_obs = 7

# %%
def invert_transformation(df_train , df_forecast , second_diff = False):

    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:
        if second_diff:
            df_fc[str(col) + '_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col) + '_2d'].cumsum()

        df_fc[str(col) + '_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)].cumsum()

    return df_fc

# %%
resultados_arima = invert_transformation(pd.DataFrame(serie_filtrada['AUM FIC'][-n_obs:])[-n_obs:],pred_arima[-n_obs:],second_diff=False)

resultados_arima
# Out:
#                  AUM FIC  AUM FIC_forecast
# 2024-05-18 -4.051748e+05      7.493137e+07
# 2024-05-25 -1.523554e+05      7.477902e+07
# 2024-06-01 -6.927203e+05      7.408630e+07
# 2024-06-08 -4.384398e+05      7.364786e+07
# 2024-06-15 -9.160886e+05      7.273177e+07
# 2024-06-22 -7.668110e+05      7.196496e+07
# 2024-06-29 -1.125847e+06      7.083911e+07

# %%
plt.rcParams['figure.figsize'] = (20,8)

sns.lineplot(resultados_arima, x= resultados_arima.index, y=resultados_arima['AUM FIC_forecast'],label = 'AUM FIC Forecast')

sns.lineplot(serie_filtrada[-n_obs:], x= serie_filtrada.index[-n_obs:], y=serie_filtrada['AUM FIC'][-n_obs:],label = 'AUM FIC')

plt.show()

# %% [markdown]
# # ARIMAX

# %%
serie_dif
# Out:
#                  AUM FIC     Efectivo
# Fecha
# 2018-01-06   6734.988641 -1912.465334
# 2018-01-13   7047.624598 -1158.360789
# 2018-01-20   6779.730104 -1210.942647
# 2018-01-27   8954.972046  1139.615413
# 2018-02-03   6038.756100 -1013.654724
# ...                  ...          ...
# 2024-06-01  22557.398097  1160.292575
# 2024-06-08  21575.713932  -320.642989
# 2024-06-15  20545.053360   125.324028
# 2024-06-22  17301.417742  2068.283621
# 2024-06-29  24667.715961  2645.747965
#
# [339 rows x 2 columns]

# %%
exogenas = serie_dif[['AUM FIC','Efectivo']]

scaler = StandardScaler()

exogenas_escaladas = scaler.fit_transform(exogenas[['AUM FIC','Efectivo']])

exogenas[['AUM FIC','Efectivo']] = exogenas_escaladas

train_ex = exogenas.iloc[:332]

test_ex = exogenas.iloc[332:]

model_arimax = ARIMA(train_ex['AUM FIC'],exog=train_ex[['AUM FIC','Efectivo']], order=(2,3,3))

results_arimax = model_arimax.fit()

print(results_arimax.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                AUM FIC   No. Observations:                  332
# Model:                 ARIMA(2, 3, 3)   Log Likelihood                3140.102
# Date:                Thu, 28 Nov 2024   AIC                          -6264.203
# Time:                        21:49:06   BIC                          -6233.835
# Sample:                    01-06-2018   HQIC                         -6252.089
#                          - 05-11-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AUM FIC        1.0000   2.28e-07   4.39e+06      0.000       1.000       1.000
# Efectivo   -7.665e-07   1.79e-06     -0.429      0.668   -4.27e-06    2.74e-06
# ar.L1         -0.9533   2.57e-11   -3.7e+10      0.000      -0.953      -0.953
# ar.L2         -0.3232   1.58e-11  -2.04e+10      0.000      -0.323      -0.323
# ma.L1         -0.7901   8.02e-12  -9.85e+10      0.000      -0.790      -0.790
# ma.L2         -0.2707   1.72e-11  -1.57e+10      0.000      -0.271      -0.271
# ma.L3          0.3025   4.38e-12    6.9e+10      0.000       0.302       0.302
# sigma2      5.451e-10   1.38e-10      3.947      0.000    2.74e-10    8.16e-10
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.36   Jarque-Bera (JB):             62961.86
# Prob(Q):                              0.07   Prob(JB):                         0.00
# Heteroskedasticity (H):             231.59   Skew:                             3.06
# Prob(H) (two-sided):                  0.00   Kurtosis:                        70.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.15e+27. Standard errors may be unstable.

# %%
start = len(train_ex)

end = len(train_ex) + len(test_ex) - 1

rename = f'ARIMAX Predictions'

fcast_arimax = results_arimax.predict(start = start, end = end ,exog =  test_ex[['AUM FIC','Efectivo']] ,dynamic=False).rename(rename)

# %%
pred_arimax = pd.DataFrame(fcast_arimax,index=fcast_arimax.index)

pred_arimax = pred_arimax.rename(columns={'ARIMAX Predictions': 'AUM FIC'})

pred_arimax
# Out:
#              AUM FIC
# 2024-05-18  0.179806
# 2024-05-25  0.180456
# 2024-06-01  0.185528
# 2024-06-08  0.176575
# 2024-06-15  0.167171
# 2024-06-22  0.137551
# 2024-06-29  0.204868

# %%
resultados_arimax = invert_transformation(pd.DataFrame(serie_filtrada['AUM FIC'][-n_obs:])[-n_obs:],pred_arimax[-n_obs:],second_diff=False)

resultados_arimax
# Out:
#              AUM FIC  AUM FIC_forecast
# 2024-05-18  0.179806      7.533655e+07
# 2024-05-25  0.180456      7.533655e+07
# 2024-06-01  0.185528      7.533655e+07
# 2024-06-08  0.176575      7.533655e+07
# 2024-06-15  0.167171      7.533655e+07
# 2024-06-22  0.137551      7.533655e+07
# 2024-06-29  0.204868      7.533655e+07

# %%
plt.rcParams['figure.figsize'] = (20,8)

sns.lineplot(resultados_arimax, x= resultados_arimax.index, y=resultados_arimax['AUM FIC_forecast'],label = 'AUM FIC Forecast')

sns.lineplot(serie_filtrada[-n_obs:], x= serie_filtrada.index[-n_obs:], y=serie_filtrada['AUM FIC'][-n_obs:],label = 'AUM FIC')

plt.show()

# %%
def calculate_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return mse, rmse, mae, mape

# %%
metricas_arima =  calculate_metrics(pd.DataFrame(serie_filtrada['AUM FIC'][-n_obs:]),pd.DataFrame(resultados_arima['AUM FIC_forecast']))

metricas_arimax = calculate_metrics(pd.DataFrame(serie_filtrada['AUM FIC'][-n_obs:]),pd.DataFrame(resultados_arimax['AUM FIC_forecast']))

# %%
# Comparar resultados
resultados = pd.DataFrame({
    'Model': ['ARIMA','ARIMAX',],
    'MSE': [metricas_arima[0],metricas_arimax[0]],
    'RMSE': [metricas_arima[1],metricas_arimax[1]],
    'MAE': [metricas_arima[2],metricas_arimax[2]],
    'MAPE': [metricas_arima[3],metricas_arimax[3]]
})

resultados
# Out:
#     Model           MSE          RMSE           MAE  MAPE
# 0   ARIMA  1.542285e+13  3.927194e+06  3.805878e+06   NaN
# 1  ARIMAX  4.658559e+12  2.158370e+06  1.752242e+06   NaN

# %% [markdown]
# # VAR 1 - Las variables con correlación del AUM mayor a 0.5

# %% [markdown]
# ### Estacionariedad

# %%
def estacionariedad(df):

    for i  in df.columns:

        a = sts.adfuller(df[i])[1]

        if a > 0.05:

            print(f'Serie de tiempo {i}')
            
            print(f'El valor p de {i} es de: {round(a,4)}, por esto la serie no es estacionaria')

            

        else:
            
            print(f'Serie de tiempo {i}')
            print(f'El valor p de {i} es de: {round(a,4)}, por esto la serie es estacionaria')

# %%
estacionariedad(df)
# Out:
# Serie de tiempo AUM FIC
# El valor p de AUM FIC es de: 0.7215, por esto la serie no es estacionaria
# Serie de tiempo Efectivo
# El valor p de Efectivo es de: 0.8202, por esto la serie no es estacionaria
# Serie de tiempo Reserva Bancaria
# El valor p de Reserva Bancaria es de: 0.5277, por esto la serie no es estacionaria
# Serie de tiempo Del sector privado
# El valor p de Del sector privado es de: 0.5455, por esto la serie no es estacionaria
# Serie de tiempo Del sector público
# El valor p de Del sector público es de: 0.0053, por esto la serie es estacionaria
# Serie de tiempo Cuentas de ahorro
# El valor p de Cuentas de ahorro es de: 0.7389, por esto la serie no es estacionaria
# Serie de tiempo CDT 1/
# El valor p de CDT 1/ es de: 0.9862, por esto la serie no es estacionaria
# Serie de tiempo Otros depósitos a la vista
# El valor p de Otros depósitos a la vista es de: 0.6422, por esto la serie no es estacionaria
# Serie de tiempo Inflación anual %
# El valor p de Inflación anual % es de: 0.86, por esto la serie no es estacionaria
# Serie de tiempo Tasa de intervención de política monetaria (%)
# El valor p de Tasa de intervención de política monetaria (%) es de: 0.9779, por esto la serie no es estacionaria
# Serie de tiempo Tasa 30 días
# El valor p de Tasa 30 días es de: 0.9429, por esto la serie no es estacionaria
# Serie de tiempo Tasa Entre 31 y 44 días
# El valor p de Tasa Entre 31 y 44 días es de: 0.9203, por esto la serie no es estacionaria
# Serie de tiempo Tasa A 45 días
# El valor p de Tasa A 45 días es de: 0.9116, por esto la serie no es estacionaria
# Serie de tiempo Tasa Entre 46 y 59 días
# El valor p de Tasa Entre 46 y 59 días es de: 0.8945, por esto la serie no es estacionaria
# Serie de tiempo Tasa A 60 días
# El valor p de Tasa A 60 días es de: 0.934, por esto la serie no es estacionaria
# Serie de tiempo Tasa Entre 61 y 89 días
# El valor p de Tasa Entre 61 y 89 días es de: 0.919, por esto la serie no es estacionaria
# Serie de tiempo Tasa A 90 días
# El valor p de Tasa A 90 días es de: 0.8827, por esto la serie no es estacionaria
# Serie de tiempo Tasa Entre 91 y 119 días
# El valor p de Tasa Entre 91 y 119 días es de: 0.9026, por esto la serie no es estacionaria
# Serie de tiempo Tasa A 120 días
# El valor p de Tasa A 120 días es de: 0.9201, por esto la serie no es estacionaria
# Serie de tiempo Tasa Entre 121 y 179 días
# El valor p de Tasa Entre 121 y 179 días es de: 0.8981, por esto la serie no es estacionaria
# Serie de tiempo Tasa A 180 días
# El valor p de Tasa A 180 días es de: 0.8846, por esto la serie no es estacionaria
# Serie de tiempo Tasa Entre 181 y 359 días
# El valor p de Tasa Entre 181 y 359 días es de: 0.8562, por esto la serie no es estacionaria
# Serie de tiempo Tasa A 360 días
# El valor p de Tasa A 360 días es de: 0.8475, por esto la serie no es estacionaria
# Serie de tiempo Tasa Superiores a 360 días
# El valor p de Tasa Superiores a 360 días es de: 0.8109, por esto la serie no es estacionaria
# Serie de tiempo Tasa Captaciones a través de CDT por red de oficinas
# El valor p de Tasa Captaciones a través de CDT por red de oficinas es de: 0.8674, por esto la serie no es estacionaria
# Serie de tiempo Tasa Captaciones a través de CDT por tesorería
# El valor p de Tasa Captaciones a través de CDT por tesorería es de: 0.8382, por esto la serie no es estacionaria
# Serie de tiempo Valor hoy
# El valor p de Valor hoy es de: 0.5695, por esto la serie no es estacionaria
# Serie de tiempo VALOR
# El valor p de VALOR es de: 0.3706, por esto la serie no es estacionaria

# %% [markdown]
# ### Transformar los datos

# %%
serie2 = df[['AUM FIC','Efectivo','CDT 1/','Otros depósitos a la vista','Valor hoy','Tasa 30 días',
       'Tasa A 45 días', 'Cuentas de ahorro',
       'VALOR']]

serie_dif_2 = serie2.diff().dropna()

serie_dif_2 = serie_dif_2[(serie_dif_2 != 0).all(axis=1)]

serie_dif_2
# Out:
#                  AUM FIC     Efectivo       CDT 1/  \
# Fecha
# 2019-07-27  33618.542030  1815.020698    65.212852
# 2019-08-03   9543.654538  -410.134295     3.364935
# 2019-08-17  13168.781914  -971.019228   236.825393
# 2019-08-24   8147.554790   886.748653  -443.567393
# 2019-08-31   9889.951959  1243.219915    21.059481
# ...                  ...          ...          ...
# 2024-06-01  22557.398097  1160.292575    13.080693
# 2024-06-08  21575.713932  -320.642989  -217.978039
# 2024-06-15  20545.053360   125.324028  1416.754917
# 2024-06-22  17301.417742  2068.283621  1852.757649
# 2024-06-29  24667.715961  2645.747965   147.132497
#
#             Otros depósitos a la vista  Valor hoy  Tasa 30 días  \
# Fecha
# 2019-07-27                  860.734929      -0.72     -0.002977
# 2019-08-03                 -839.925135      -1.25     -0.000367
# 2019-08-17                 -387.128821       0.01     -0.004332
# 2019-08-24                 1201.815323       0.39      0.013062
# 2019-08-31                 -837.501222      -0.55      0.002821
# ...                                ...        ...           ...
# 2024-06-01                -1179.461882       1.54      0.000521
# 2024-06-08                  550.162359       1.38     -0.000647
# 2024-06-15                 -418.534610       0.85     -0.004460
# 2024-06-22                 1317.693033       1.53      0.004295
# 2024-06-29                 -632.930915      -0.40      0.001629
#
#             Tasa A 45 días  Cuentas de ahorro  VALOR
# Fecha
# 2019-07-27        0.010529        1847.140344  20.17
# 2019-08-03       -0.018604         826.068489  36.55
# 2019-08-17        0.022212       -2445.212410  -6.36
# 2019-08-24        0.006672        3359.251033  22.96
# 2019-08-31        0.005014        -328.482535 -36.86
# ...                    ...                ...    ...
# 2024-06-01        0.007839        3670.369404 -13.40
# 2024-06-08       -0.001704        -900.516744   5.61
# 2024-06-15       -0.000330       -3444.178762  44.03
# 2024-06-22        0.006913        9907.251502 -32.24
# 2024-06-29       -0.000289       -1529.331415 -10.06
#
# [233 rows x 9 columns]

# %%
estacionariedad(serie_dif_2)
# Out:
# Serie de tiempo AUM FIC
# El valor p de AUM FIC es de: 0.0, por esto la serie es estacionaria
# Serie de tiempo Efectivo
# El valor p de Efectivo es de: 0.0, por esto la serie es estacionaria
# Serie de tiempo CDT 1/
# El valor p de CDT 1/ es de: 0.0039, por esto la serie es estacionaria
# Serie de tiempo Otros depósitos a la vista
# El valor p de Otros depósitos a la vista es de: 0.0, por esto la serie es estacionaria
# Serie de tiempo Valor hoy
# El valor p de Valor hoy es de: 0.0, por esto la serie es estacionaria
# Serie de tiempo Tasa 30 días
# El valor p de Tasa 30 días es de: 0.0, por esto la serie es estacionaria
# Serie de tiempo Tasa A 45 días
# El valor p de Tasa A 45 días es de: 0.0, por esto la serie es estacionaria
# Serie de tiempo Cuentas de ahorro
# El valor p de Cuentas de ahorro es de: 0.0222, por esto la serie es estacionaria
# Serie de tiempo VALOR
# El valor p de VALOR es de: 0.0, por esto la serie es estacionaria

# %% [markdown]
# ### Conjunto de entrenamiento y prueba

# %%
train2 = serie_dif_2.iloc[:226]

test2 = serie_dif_2.iloc[226:]

print(train2.shape)

print(test2.shape)
# Out:
# (226, 9)
# (7, 9)

# %% [markdown]
# ### Modelo VAR

# %%
model_var_2 = VAR(train2)

resultados_var_2 = model_var_2.select_order()

resultados_var_2.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
resultados_var_2.selected_orders
# Out:
# {'aic': 1, 'bic': 0, 'hqic': 1, 'fpe': 1}

# %%
resultados_var_2 = model_var_2.fit(maxlags=1, ic= 'aic',method='ols')

display(resultados_var_2.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 28, Nov, 2024
# Time:                     21:49:09
# --------------------------------------------------------------------
# No. of Equations:         9.00000    BIC:                    74.4673
# Nobs:                     225.000    HQIC:                   73.6523
# Log likelihood:          -11007.2    FPE:                5.59129e+31
# AIC:                      73.1008    Det(Omega_mle):     3.78046e+31
# --------------------------------------------------------------------
# Results for equation AUM FIC
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                             -9562.502957      9675.510247           -0.988           0.323
# L1.AUM FIC                            0.245631         0.065736            3.737           0.000
# L1.Efectivo                          -1.066937         8.720607           -0.122           0.903
# L1.CDT 1/                            15.137646         6.945048            2.180           0.029
# L1.Otros depósitos a la vista        19.830451        13.395396            1.480           0.139
# L1.Valor hoy                        -16.875757       546.921585           -0.031           0.975
# L1.Tasa 30 días                 -679928.578832   1667747.450490           -0.408           0.683
# L1.Tasa A 45 días               -610885.882086    937495.013301           -0.652           0.515
# L1.Cuentas de ahorro                 -0.820513         2.889508           -0.284           0.776
# L1.VALOR                             93.633055       278.527685            0.336           0.737
# ================================================================================================
#
# Results for equation Efectivo
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                               212.411750        82.299471            2.581           0.010
# L1.AUM FIC                            0.000460         0.000559            0.823           0.411
# L1.Efectivo                          -0.243705         0.074177           -3.285           0.001
# L1.CDT 1/                            -0.191103         0.059074           -3.235           0.001
# L1.Otros depósitos a la vista         0.312938         0.113941            2.747           0.006
# L1.Valor hoy                          3.967854         4.652091            0.853           0.394
# L1.Tasa 30 días                    6333.073261     14185.787534            0.446           0.655
# L1.Tasa A 45 días                  4787.885254      7974.291952            0.600           0.548
# L1.Cuentas de ahorro                  0.112836         0.024578            4.591           0.000
# L1.VALOR                             -0.220332         2.369144           -0.093           0.926
# ================================================================================================
#
# Results for equation CDT 1/
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                               195.704894        72.130071            2.713           0.007
# L1.AUM FIC                            0.000642         0.000490            1.309           0.190
# L1.Efectivo                          -0.064080         0.065011           -0.986           0.324
# L1.CDT 1/                             0.660852         0.051775           12.764           0.000
# L1.Otros depósitos a la vista         0.086524         0.099861            0.866           0.386
# L1.Valor hoy                          0.251220         4.077252            0.062           0.951
# L1.Tasa 30 días                    4028.634075     12432.909298            0.324           0.746
# L1.Tasa A 45 días                 -9097.584425      6988.942159           -1.302           0.193
# L1.Cuentas de ahorro                  0.002115         0.021541            0.098           0.922
# L1.VALOR                             -0.712300         2.076399           -0.343           0.732
# ================================================================================================
#
# Results for equation Otros depósitos a la vista
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                               119.852394        53.247751            2.251           0.024
# L1.AUM FIC                           -0.000061         0.000362           -0.169           0.866
# L1.Efectivo                          -0.011729         0.047993           -0.244           0.807
# L1.CDT 1/                            -0.068688         0.038221           -1.797           0.072
# L1.Otros depósitos a la vista        -0.181537         0.073720           -2.463           0.014
# L1.Valor hoy                          0.471209         3.009903            0.157           0.876
# L1.Tasa 30 días                  -14900.353061      9178.203337           -1.623           0.104
# L1.Tasa A 45 días                   247.152936      5159.366220            0.048           0.962
# L1.Cuentas de ahorro                 -0.022777         0.015902           -1.432           0.152
# L1.VALOR                             -0.511135         1.532836           -0.333           0.739
# ================================================================================================
#
# Results for equation Valor hoy
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                                 0.999693         1.233199            0.811           0.418
# L1.AUM FIC                            0.000001         0.000008            0.102           0.919
# L1.Efectivo                          -0.000417         0.001111           -0.376           0.707
# L1.CDT 1/                            -0.000211         0.000885           -0.239           0.811
# L1.Otros depósitos a la vista         0.000445         0.001707            0.261           0.794
# L1.Valor hoy                         -0.021839         0.069708           -0.313           0.754
# L1.Tasa 30 días                     124.020972       212.563928            0.583           0.560
# L1.Tasa A 45 días                    82.340741       119.489088            0.689           0.491
# L1.Cuentas de ahorro                  0.000050         0.000368            0.134           0.893
# L1.VALOR                             -0.004796         0.035500           -0.135           0.893
# ================================================================================================
#
# Results for equation Tasa 30 días
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                                 0.000145         0.000404            0.360           0.719
# L1.AUM FIC                            0.000000         0.000000            0.244           0.807
# L1.Efectivo                           0.000000         0.000000            1.240           0.215
# L1.CDT 1/                            -0.000000         0.000000           -0.049           0.961
# L1.Otros depósitos a la vista        -0.000000         0.000001           -0.278           0.781
# L1.Valor hoy                         -0.000007         0.000023           -0.291           0.771
# L1.Tasa 30 días                       0.045044         0.069556            0.648           0.517
# L1.Tasa A 45 días                    -0.024341         0.039100           -0.623           0.534
# L1.Cuentas de ahorro                  0.000000         0.000000            0.377           0.707
# L1.VALOR                             -0.000010         0.000012           -0.902           0.367
# ================================================================================================
#
# Results for equation Tasa A 45 días
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                                 0.000977         0.000717            1.362           0.173
# L1.AUM FIC                            0.000000         0.000000            0.322           0.747
# L1.Efectivo                           0.000000         0.000001            0.494           0.621
# L1.CDT 1/                             0.000000         0.000001            0.377           0.706
# L1.Otros depósitos a la vista        -0.000000         0.000001           -0.024           0.981
# L1.Valor hoy                         -0.000009         0.000041           -0.212           0.832
# L1.Tasa 30 días                       0.039885         0.123641            0.323           0.747
# L1.Tasa A 45 días                    -0.015646         0.069503           -0.225           0.822
# L1.Cuentas de ahorro                 -0.000000         0.000000           -1.698           0.089
# L1.VALOR                              0.000017         0.000021            0.817           0.414
# ================================================================================================
#
# Results for equation Cuentas de ahorro
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                               823.532612       253.967823            3.243           0.001
# L1.AUM FIC                            0.000102         0.001725            0.059           0.953
# L1.Efectivo                          -0.774297         0.228903           -3.383           0.001
# L1.CDT 1/                            -0.778873         0.182297           -4.273           0.000
# L1.Otros depósitos a la vista         0.350057         0.351609            0.996           0.319
# L1.Valor hoy                         -0.225462        14.355882           -0.016           0.987
# L1.Tasa 30 días                   29975.466503     43775.902021            0.685           0.494
# L1.Tasa A 45 días                 54065.876271     24607.856444            2.197           0.028
# L1.Cuentas de ahorro                  0.056493         0.075845            0.745           0.456
# L1.VALOR                              2.759376         7.310939            0.377           0.706
# ================================================================================================
#
# Results for equation VALOR
# ================================================================================================
#                                    coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------
# const                                -2.668261         2.360117           -1.131           0.258
# L1.AUM FIC                           -0.000010         0.000016           -0.601           0.548
# L1.Efectivo                          -0.001269         0.002127           -0.596           0.551
# L1.CDT 1/                             0.000305         0.001694            0.180           0.857
# L1.Otros depósitos a la vista        -0.010440         0.003267           -3.195           0.001
# L1.Valor hoy                         -0.026787         0.133409           -0.201           0.841
# L1.Tasa 30 días                    -218.495512       406.808494           -0.537           0.591
# L1.Tasa A 45 días                   129.236955       228.680269            0.565           0.572
# L1.Cuentas de ahorro                  0.001299         0.000705            1.843           0.065
# L1.VALOR                             -0.046134         0.067940           -0.679           0.497
# ================================================================================================
#
# Correlation matrix of residuals
#                                AUM FIC  Efectivo    CDT 1/  Otros depósitos a la vista  Valor hoy  Tasa 30 días  Tasa A 45 días  Cuentas de ahorro     VALOR
# AUM FIC                       1.000000  0.096023 -0.089147                    0.087028   0.018019     -0.004838       -0.000023           0.045976 -0.090761
# Efectivo                      0.096023  1.000000  0.076293                    0.553665   0.007954      0.111178        0.078293           0.468351  0.088872
# CDT 1/                       -0.089147  0.076293  1.000000                    0.068553   0.141966      0.070486        0.030242          -0.004008  0.067660
# Otros depósitos a la vista    0.087028  0.553665  0.068553                    1.000000   0.053359      0.108608        0.007144           0.353033  0.114465
# Valor hoy                     0.018019  0.007954  0.141966                    0.053359   1.000000     -0.031428       -0.044229           0.117587  0.115191
# Tasa 30 días                 -0.004838  0.111178  0.070486                    0.108608  -0.031428      1.000000        0.223076           0.038304  0.001576
# Tasa A 45 días               -0.000023  0.078293  0.030242                    0.007144  -0.044229      0.223076        1.000000           0.060293  0.113021
# Cuentas de ahorro             0.045976  0.468351 -0.004008                    0.353033   0.117587      0.038304        0.060293           1.000000  0.020852
# VALOR                        -0.090761  0.088872  0.067660                    0.114465   0.115191      0.001576        0.113021           0.020852  1.000000

# %% [markdown]
# ### Prueba de causalidad de Wiener-Granger
#
# #### Ho: La variable seleccionada no "causa en el sentido de Granger" a las demás variables
#
# #### H1:La variable seleccionada si "causa en el sentido de Granger" a las demás variables
#
# p-valor < 0.05 Rechazo Ho y mantengo la variable dentro del modelo

# %% [markdown]
# AUM FIC

# %%
grangercaus = resultados_var_2.test_causality(['Efectivo','CDT 1/','Otros depósitos a la vista','Valor hoy','Tasa 30 días',
       'Tasa A 45 días', 'Cuentas de ahorro',
       'VALOR'],['AUM FIC'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Efectivo

# %%
grangercaus = resultados_var_2.test_causality(['AUM FIC','CDT 1/','Otros depósitos a la vista','Valor hoy','Tasa 30 días',
       'Tasa A 45 días', 'Cuentas de ahorro',
       'VALOR'],['Efectivo'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# CDT

# %%
grangercaus = resultados_var_2.test_causality(['AUM FIC','Efectivo','Otros depósitos a la vista','Valor hoy','Tasa 30 días',
       'Tasa A 45 días', 'Cuentas de ahorro',
       'VALOR'],['CDT 1/'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Otros depositos a la vista

# %%
grangercaus = resultados_var_2.test_causality(['AUM FIC','Efectivo','CDT 1/','Valor hoy','Tasa 30 días',
       'Tasa A 45 días', 'Cuentas de ahorro',
       'VALOR'],['Otros depósitos a la vista'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Valor COLTES

# %%
grangercaus = resultados_var_2.test_causality(['AUM FIC','Efectivo','CDT 1/','Otros depósitos a la vista','Tasa 30 días',
       'Tasa A 45 días', 'Cuentas de ahorro',
       'VALOR'],['Valor hoy'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Tasa 30 días

# %%
grangercaus = resultados_var_2.test_causality(['AUM FIC','Efectivo','CDT 1/','Otros depósitos a la vista','Valor hoy',
       'Tasa A 45 días', 'Cuentas de ahorro',
       'VALOR'],['Tasa 30 días'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Tasa a 45 días

# %%
grangercaus = resultados_var_2.test_causality(['AUM FIC','Efectivo','CDT 1/','Otros depósitos a la vista','Valor hoy','Tasa 30 días',
        'Cuentas de ahorro',
       'VALOR'],['Tasa A 45 días'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Cuentas de ahorro

# %%
grangercaus = resultados_var_2.test_causality(['AUM FIC','Efectivo','CDT 1/','Otros depósitos a la vista','Valor hoy','Tasa 30 días',
       'Tasa A 45 días',
       'VALOR'],['Cuentas de ahorro'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Valor Dólar

# %%
grangercaus = resultados_var_2.test_causality(['AUM FIC','Efectivo','CDT 1/','Otros depósitos a la vista','Valor hoy','Tasa 30 días',
       'Tasa A 45 días','Cuentas de ahorro'
       ],['VALOR'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Matriz de causalidad de Granger

# %%
lag_order = resultados_var_2.k_ar

test = 'ssr_chi2test'

def granger_causality_matrix(train_transformed, variables, test = 'ssr_chi2test', verbose = False ):

    dataset = pd.DataFrame(np.zeros((len(variables),len(variables))),columns=variables, index=variables)

    for c in dataset.columns:
        for r in dataset.index:

            test_result = grangercausalitytests(train_transformed[[r,c]],maxlag=lag_order,verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(lag_order)]

            if verbose:

                print(f'Y = {r}, X = {c}, P Values = {p_values}')

            min_p_value = np.min(p_values)
            dataset.loc[r,c]   = min_p_value

    dataset.columns = [var + '_x' for var in variables]

    dataset.index = [var + '_y' for var in variables]

    return dataset

# %%
granger_causality_matrix(train2,variables=train2.columns)
# Out:
#                               AUM FIC_x  Efectivo_x  CDT 1/_x  \
# AUM FIC_y                        1.0000      0.8859    0.0238
# Efectivo_y                       0.6958      1.0000    0.0004
# CDT 1/_y                         0.1845      0.5119    1.0000
# Otros depósitos a la vista_y     0.8280      0.3805    0.1033
# Valor hoy_y                      0.9241      0.8763    0.8637
# Tasa 30 días_y                   0.6616      0.1173    0.7293
# Tasa A 45 días_y                 0.7587      0.7413    0.4644
# Cuentas de ahorro_y              0.6397      0.0027    0.0001
# VALOR_y                          0.3861      0.2035    0.9351
#
#                               Otros depósitos a la vista_x  Valor hoy_x  \
# AUM FIC_y                                           0.1438       0.7736
# Efectivo_y                                          0.0006       0.2426
# CDT 1/_y                                            0.5967       0.9031
# Otros depósitos a la vista_y                        1.0000       0.8488
# Valor hoy_y                                         0.8291       1.0000
# Tasa 30 días_y                                      0.7416       0.7604
# Tasa A 45 días_y                                    0.7531       0.7327
# Cuentas de ahorro_y                                 0.9156       0.6701
# VALOR_y                                             0.0010       0.9594
#
#                               Tasa 30 días_x  Tasa A 45 días_x  \
# AUM FIC_y                             0.7249            0.5495
# Efectivo_y                            0.7737            0.5338
# CDT 1/_y                              0.9920            0.1854
# Otros depósitos a la vista_y          0.0808            0.6148
# Valor hoy_y                           0.4623            0.4074
# Tasa 30 días_y                        1.0000            0.4884
# Tasa A 45 días_y                      0.7095            1.0000
# Cuentas de ahorro_y                   0.5097            0.0371
# VALOR_y                               0.4478            0.6037
#
#                               Cuentas de ahorro_x  VALOR_x
# AUM FIC_y                                  0.7970   0.5369
# Efectivo_y                                 0.0000   0.8659
# CDT 1/_y                                   0.8536   0.5645
# Otros depósitos a la vista_y               0.1813   0.7647
# Valor hoy_y                                0.9004   0.9438
# Tasa 30 días_y                             0.3135   0.3161
# Tasa A 45 días_y                           0.0636   0.4392
# Cuentas de ahorro_y                        1.0000   0.7289
# VALOR_y                                    0.5627   1.0000

# %% [markdown]
# ### Residuos

# %%
residuos = resultados_var_2.resid

# %%
# Gráfico de los residuos
fig, axs = plt.subplots(9)

fig.suptitle('Gráficos de los residuos', fontsize = 20)

fig.set_size_inches(18,10)

[axs[i].plot(residuos.iloc[:,i]) for i in range(9)]

plt.show()

# %% [markdown]
# Dickey Fuller a los residuos

# %%
[sts.adfuller(residuos.iloc[:,i])[1] for i in range(9)]
# Out:
# [7.706209625751821e-27,
#  1.0670265057957749e-09,
#  0.0024979816634564844,
#  1.2733967454300321e-23,
#  1.6667482980584463e-27,
#  2.8049594142827648e-06,
#  1.3825482362118398e-19,
#  5.905671286053675e-07,
#  2.898132109074822e-08]

# %% [markdown]
# Los residuos son estacionarios

# %% [markdown]
# ### Valores Predichos

# %%
y_fitted = resultados_var_2.fittedvalues

fig , axs = plt.subplots(11)

fig.suptitle ('Gráficos de los valores predichos por el modelo',fontsize = 20)

fig.set_size_inches(18,10)

[axs[i].plot(y_fitted.iloc[:,i]) for i in range (9)]

plt.show()

# %%
lag_order = resultados_var_2.k_ar

input_data_2 = train2.values[-lag_order:]

# Forecasting

prediccion_2 = resultados_var_2.forecast(y=input_data_2,steps=n_obs)

prediccion_2 = (pd.DataFrame(prediccion_2,index=test2[-n_obs:].index, columns= test2.columns + '_pred'))

print('Predicciones')

prediccion_2
# Out:
# Predicciones
#             AUM FIC_pred  Efectivo_pred  CDT 1/_pred  \
# Fecha
# 2024-05-18  -2476.722889    -161.035781   345.483500
# 2024-05-25  -1885.820076     358.895490   440.533401
# 2024-06-01  -4467.032804     163.408830   465.397325
# 2024-06-08  -3750.467857     142.926247   491.822760
# 2024-06-15  -3268.004297     159.885131   510.077019
# 2024-06-22  -2892.147365     152.194116   521.565877
# 2024-06-29  -2626.044580     148.184855   529.648690
#
#             Otros depósitos a la vista_pred  Valor hoy_pred  \
# Fecha
# 2024-05-18                       252.725971        0.839169
# 2024-05-25                        39.327972        1.296477
# 2024-06-01                        59.758710        0.862288
# 2024-06-08                        65.147348        0.967502
# 2024-06-15                        62.068664        0.982583
# 2024-06-22                        60.911131        0.963185
# 2024-06-29                        60.988433        0.964460
#
#             Tasa 30 días_pred  Tasa A 45 días_pred  Cuentas de ahorro_pred  \
# Fecha
# 2024-05-18          -0.000058             0.001997              726.690967
# 2024-05-25           0.000041             0.000616              904.472795
# 2024-06-01           0.000351             0.000764              291.483189
# 2024-06-08           0.000226             0.000966              417.532263
# 2024-06-15           0.000219             0.000896              426.717054
# 2024-06-22           0.000227             0.000907              395.515258
# 2024-06-29           0.000222             0.000919              391.227631
#
#             VALOR_pred
# Fecha
# 2024-05-18   -3.605665
# 2024-05-25   -3.614920
# 2024-06-01   -2.004373
# 2024-06-08   -2.844631
# 2024-06-15   -2.620736
# 2024-06-22   -2.615522
# 2024-06-29   -2.634281

# %%
def invert_transformation(df_train , df_forecast , second_diff = False):

    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:
        if second_diff:
            df_fc[str(col) + '_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col) + '_2d'].cumsum()

        df_fc[str(col) + '_pred'] = df_train[col].iloc[-1] + df_fc[str(col)+'_pred'].cumsum()

    return df_fc

# %%
# Traer el dataset original

lista = serie_dif_2.index

serie_filtrada_2 = serie2.loc[lista]

serie_filtrada_2
# Out:
#                  AUM FIC       Efectivo         CDT 1/  \
# Fecha
# 2019-07-27  5.281838e+07   63309.722270  174724.088504
# 2019-08-03  5.334741e+07   62899.587974  174727.453439
# 2019-08-17  5.369593e+07   61706.721473  175307.328212
# 2019-08-24  5.335509e+07   62593.470127  174863.760820
# 2019-08-31  5.329419e+07   63836.690042  174884.820301
# ...                  ...            ...            ...
# 2024-06-01  7.587088e+07  108830.824490  305755.773893
# 2024-06-08  7.707061e+07  108510.181501  305537.795854
# 2024-06-15  7.657252e+07  108635.505529  306954.550771
# 2024-06-22  7.708270e+07  110703.789150  308807.308420
# 2024-06-29  7.533655e+07  113349.537115  308954.440917
#
#             Otros depósitos a la vista  Valor hoy  Tasa 30 días  \
# Fecha
# 2019-07-27                 5616.324019     286.11      0.017845
# 2019-08-03                 4776.398885     284.93      0.018803
# 2019-08-17                 4609.487949     287.77      0.014432
# 2019-08-24                 5811.303271     286.88      0.016849
# 2019-08-31                 4973.802049     285.91      0.020190
# ...                                ...        ...           ...
# 2024-06-01                10301.086517     336.88      0.093941
# 2024-06-08                10851.248876     340.15      0.093421
# 2024-06-15                10432.714266     336.93      0.094052
# 2024-06-22                11750.407298     339.74      0.095873
# 2024-06-29                11117.476384     340.60      0.094103
#
#             Tasa A 45 días  Cuentas de ahorro    VALOR
# Fecha
# 2019-07-27        0.040455      187040.794645  3233.26
# 2019-08-03        0.010344      187866.863134  3365.78
# 2019-08-17        0.034729      184358.911006  3441.40
# 2019-08-24        0.019300      187718.162039  3399.95
# 2019-08-31        0.006014      187389.679505  3427.29
# ...                    ...                ...      ...
# 2024-06-01        0.095101      294865.576409  3860.92
# 2024-06-08        0.091220      293965.059665  3944.14
# 2024-06-15        0.092746      290520.880903  4151.55
# 2024-06-22        0.094564      300428.132405  4143.72
# 2024-06-29        0.095236      298898.800990  4148.04
#
# [233 rows x 9 columns]

# %%
output_2 = invert_transformation(serie_filtrada_2[-n_obs:],prediccion_2)

output_2
# Out:
#             AUM FIC_pred  Efectivo_pred    CDT 1/_pred  \
# Fecha
# 2024-05-18  7.533407e+07  113188.501334  309299.924417
# 2024-05-25  7.533218e+07  113547.396823  309740.457818
# 2024-06-01  7.532772e+07  113710.805653  310205.855143
# 2024-06-08  7.532397e+07  113853.731900  310697.677903
# 2024-06-15  7.532070e+07  114013.617031  311207.754921
# 2024-06-22  7.531781e+07  114165.811147  311729.320798
# 2024-06-29  7.531518e+07  114313.996002  312258.969488
#
#             Otros depósitos a la vista_pred  Valor hoy_pred  \
# Fecha
# 2024-05-18                     11370.202355      341.439169
# 2024-05-25                     11409.530327      342.735646
# 2024-06-01                     11469.289037      343.597935
# 2024-06-08                     11534.436386      344.565436
# 2024-06-15                     11596.505050      345.548019
# 2024-06-22                     11657.416181      346.511204
# 2024-06-29                     11718.404614      347.475664
#
#             Tasa 30 días_pred  Tasa A 45 días_pred  Cuentas de ahorro_pred  \
# Fecha
# 2024-05-18           0.094045             0.097233           299625.491956
# 2024-05-25           0.094086             0.097849           300529.964751
# 2024-06-01           0.094437             0.098613           300821.447940
# 2024-06-08           0.094663             0.099578           301238.980203
# 2024-06-15           0.094882             0.100474           301665.697257
# 2024-06-22           0.095109             0.101381           302061.212516
# 2024-06-29           0.095331             0.102300           302452.440147
#
#              VALOR_pred
# Fecha
# 2024-05-18  4144.434335
# 2024-05-25  4140.819416
# 2024-06-01  4138.815042
# 2024-06-08  4135.970412
# 2024-06-15  4133.349676
# 2024-06-22  4130.734153
# 2024-06-29  4128.099872

# %%
plt.rcParams['figure.figsize'] = (20,8)

sns.lineplot(output_2, x= output_2.index, y=output_2['AUM FIC_pred'],label = 'AUM FIC Forecast')

sns.lineplot(serie_filtrada_2[-n_obs:], x= serie_filtrada_2[-n_obs:].index, y=serie_filtrada_2['AUM FIC'][-n_obs:],label = 'AUM FIC')

plt.show()

# %% [markdown]
# ### Evaluación del modelo

# %%
metricas_var_2 = calculate_metrics(serie_filtrada_2['AUM FIC'].tail(n_obs),output_2['AUM FIC_pred'])

metricas_var_2
# Out:
# (4687990540619.318, 2165176.7920009024, 1764271.4415183493, 2.2627315744965597)

# %%
# Comparar resultados
resultados = pd.DataFrame({
    'Model': ['VAR1'],
    'MSE': [metricas_var_2[0]],
    'RMSE': [metricas_var_2[1]],
    'MAE': [metricas_var_2[2]],
    'MAPE': [metricas_var_2[3]]
})

resultados
# Out:
#   Model           MSE          RMSE           MAE          MAPE
# 0  VAR1  4.687991e+12  2.165177e+06  2.165177e+06  2.165177e+06

# %%
serie_filtrada_2.columns
# Out:
# Index(['AUM FIC', 'Efectivo', 'CDT 1/', 'Otros depósitos a la vista',
#        'Valor hoy', 'Tasa 30 días', 'Tasa A 45 días', 'Cuentas de ahorro',
#        'VALOR'],
#       dtype='object')

# %% [markdown]
# ## VAR 2 - Efectivo, CDT, Otros Depósitos a la Vista, Cuentas de ahorro

# %% [markdown]
# ### Transformar los datos

# %%
serie3 = df[['AUM FIC','Efectivo','CDT 1/','Otros depósitos a la vista','Cuentas de ahorro']]

serie_dif_3 = serie3.diff().dropna()

serie_dif_3 = serie_dif_3[(serie_dif_3 != 0).all(axis=1)]

serie_dif_3
# Out:
#                  AUM FIC     Efectivo       CDT 1/  \
# Fecha
# 2018-01-06   6734.988641 -1912.465334   -67.310789
# 2018-01-13   7047.624598 -1158.360789  1177.492029
# 2018-01-20   6779.730104 -1210.942647  1198.851193
# 2018-01-27   8954.972046  1139.615413   482.948687
# 2018-02-03   6038.756100 -1013.654724   721.818570
# ...                  ...          ...          ...
# 2024-06-01  22557.398097  1160.292575    13.080693
# 2024-06-08  21575.713932  -320.642989  -217.978039
# 2024-06-15  20545.053360   125.324028  1416.754917
# 2024-06-22  17301.417742  2068.283621  1852.757649
# 2024-06-29  24667.715961  2645.747965   147.132497
#
#             Otros depósitos a la vista  Cuentas de ahorro
# Fecha
# 2018-01-06                 -803.944701        -765.070154
# 2018-01-13                  159.989913       -2382.466305
# 2018-01-20                 -304.867989       -4088.346722
# 2018-01-27                  663.183564        2937.103218
# 2018-02-03                 -458.416016       -2152.534280
# ...                                ...                ...
# 2024-06-01                -1179.461882        3670.369404
# 2024-06-08                  550.162359        -900.516744
# 2024-06-15                 -418.534610       -3444.178762
# 2024-06-22                 1317.693033        9907.251502
# 2024-06-29                 -632.930915       -1529.331415
#
# [339 rows x 5 columns]

# %% [markdown]
# ### Conjunto de entrenamiento y conjunto de prueba

# %%
train3 = serie_dif_3.iloc[:332]

test3 = serie_dif_3.iloc[332:]

print(train3.shape)

print(test3.shape)
# Out:
# (332, 5)
# (7, 5)

# %% [markdown]
# ### Modelo VAR

# %%
model_var_3 = VAR(train3)

resultados_var_3 = model_var_3.select_order()

resultados_var_3.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
resultados_var_3.selected_orders
# Out:
# {'aic': 15, 'bic': 2, 'hqic': 5, 'fpe': 15}

# %%
resultados_var_3 = model_var_3.fit(maxlags=15, ic= 'aic',method='ols')

display(resultados_var_3.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 28, Nov, 2024
# Time:                     21:49:11
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                    82.3484
# Nobs:                     317.000    HQIC:                   79.6423
# Log likelihood:          -14207.0    FPE:                6.71749e+33
# AIC:                      77.8424    Det(Omega_mle):     2.29372e+33
# --------------------------------------------------------------------
# Results for equation AUM FIC
# =================================================================================================
#                                     coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------
# const                              12805.356354     10692.573543            1.198           0.231
# L1.AUM FIC                             0.217012         0.062710            3.461           0.001
# L1.Efectivo                            4.784239        11.469233            0.417           0.677
# L1.CDT 1/                             10.907714         8.873489            1.229           0.219
# L1.Otros depósitos a la vista         -2.294020        15.182095           -0.151           0.880
# L1.Cuentas de ahorro                  -2.653233         2.813974           -0.943           0.346
# L2.AUM FIC                            -0.073905         0.064672           -1.143           0.253
# L2.Efectivo                           32.434224        12.064531            2.688           0.007
# L2.CDT 1/                              3.315824         9.477558            0.350           0.726
# L2.Otros depósitos a la vista        -30.382113        18.085792           -1.680           0.093
# L2.Cuentas de ahorro                  -8.162710         2.893915           -2.821           0.005
# L3.AUM FIC                            -0.000241         0.064759           -0.004           0.997
# L3.Efectivo                           -3.728465        11.868238           -0.314           0.753
# L3.CDT 1/                             -4.427668         9.563169           -0.463           0.643
# L3.Otros depósitos a la vista        -14.596056        18.926004           -0.771           0.441
# L3.Cuentas de ahorro                  -2.609876         2.937920           -0.888           0.374
# L4.AUM FIC                             0.003411         0.071417            0.048           0.962
# L4.Efectivo                            3.216126        11.623260            0.277           0.782
# L4.CDT 1/                              0.773652         9.494664            0.081           0.935
# L4.Otros depósitos a la vista        -10.111893        18.798626           -0.538           0.591
# L4.Cuentas de ahorro                   2.927775         2.948271            0.993           0.321
# L5.AUM FIC                            -0.049115         0.114524           -0.429           0.668
# L5.Efectivo                           13.028392        11.584245            1.125           0.261
# L5.CDT 1/                              6.400246         9.422872            0.679           0.497
# L5.Otros depósitos a la vista        -27.381848        18.312343           -1.495           0.135
# L5.Cuentas de ahorro                  -1.183196         2.944558           -0.402           0.688
# L6.AUM FIC                             0.005342         0.138629            0.039           0.969
# L6.Efectivo                           24.938919        11.754152            2.122           0.034
# L6.CDT 1/                            -26.233373         9.457464           -2.774           0.006
# L6.Otros depósitos a la vista        -56.336499        18.499561           -3.045           0.002
# L6.Cuentas de ahorro                  -1.974068         2.912561           -0.678           0.498
# L7.AUM FIC                             0.053485         0.154079            0.347           0.728
# L7.Efectivo                           14.231563        11.613617            1.225           0.220
# L7.CDT 1/                            -10.667195         9.598935           -1.111           0.266
# L7.Otros depósitos a la vista        -50.328312        18.757157           -2.683           0.007
# L7.Cuentas de ahorro                 -11.357992         2.913393           -3.899           0.000
# L8.AUM FIC                            -0.129369         0.165501           -0.782           0.434
# L8.Efectivo                           -3.010235        11.760639           -0.256           0.798
# L8.CDT 1/                             13.645391         9.695443            1.407           0.159
# L8.Otros depósitos a la vista        -35.255582        19.305294           -1.826           0.068
# L8.Cuentas de ahorro                   0.182494         3.010236            0.061           0.952
# L9.AUM FIC                            -0.103907         0.169175           -0.614           0.539
# L9.Efectivo                            1.818209        11.784711            0.154           0.877
# L9.CDT 1/                             24.515290         9.492335            2.583           0.010
# L9.Otros depósitos a la vista        -15.601291        19.539938           -0.798           0.425
# L9.Cuentas de ahorro                   1.704399         2.999399            0.568           0.570
# L10.AUM FIC                           -0.001928         0.171553           -0.011           0.991
# L10.Efectivo                           4.567585        12.017858            0.380           0.704
# L10.CDT 1/                            11.743432         9.308650            1.262           0.207
# L10.Otros depósitos a la vista       -10.746015        19.627050           -0.548           0.584
# L10.Cuentas de ahorro                 -1.860310         2.988515           -0.622           0.534
# L11.AUM FIC                            0.014750         0.176961            0.083           0.934
# L11.Efectivo                          -3.828435        12.148288           -0.315           0.753
# L11.CDT 1/                            -5.576313         9.368593           -0.595           0.552
# L11.Otros depósitos a la vista       -10.857155        18.999830           -0.571           0.568
# L11.Cuentas de ahorro                 -2.582632         2.879253           -0.897           0.370
# L12.AUM FIC                            0.084567         0.171801            0.492           0.623
# L12.Efectivo                          -2.193045        11.898576           -0.184           0.854
# L12.CDT 1/                           -17.364201         9.514614           -1.825           0.068
# L12.Otros depósitos a la vista        32.928616        18.174007            1.812           0.070
# L12.Cuentas de ahorro                 -1.129634         2.866984           -0.394           0.694
# L13.AUM FIC                            0.059683         0.162141            0.368           0.713
# L13.Efectivo                         -31.815625        11.656131           -2.730           0.006
# L13.CDT 1/                             8.811339         9.326367            0.945           0.345
# L13.Otros depósitos a la vista        43.921604        16.918003            2.596           0.009
# L13.Cuentas de ahorro                 -1.334769         2.929568           -0.456           0.649
# L14.AUM FIC                           -0.015822         0.148165           -0.107           0.915
# L14.Efectivo                         -21.341231        11.629778           -1.835           0.066
# L14.CDT 1/                           -12.298202         9.182401           -1.339           0.180
# L14.Otros depósitos a la vista        47.742344        15.065527            3.169           0.002
# L14.Cuentas de ahorro                  1.380682         2.909572            0.475           0.635
# L15.AUM FIC                            0.043044         0.117158            0.367           0.713
# L15.Efectivo                          -5.612253        10.665053           -0.526           0.599
# L15.CDT 1/                            -9.004614         8.516558           -1.057           0.290
# L15.Otros depósitos a la vista        59.935598        13.157238            4.555           0.000
# L15.Cuentas de ahorro                 -1.918495         2.942106           -0.652           0.514
# =================================================================================================
#
# Results for equation Efectivo
# =================================================================================================
#                                     coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------
# const                                138.875564        66.809341            2.079           0.038
# L1.AUM FIC                             0.000421         0.000392            1.075           0.282
# L1.Efectivo                            0.286206         0.071662            3.994           0.000
# L1.CDT 1/                              0.059326         0.055443            1.070           0.285
# L1.Otros depósitos a la vista          0.070688         0.094861            0.745           0.456
# L1.Cuentas de ahorro                   0.067376         0.017582            3.832           0.000
# L2.AUM FIC                            -0.000491         0.000404           -1.214           0.225
# L2.Efectivo                            0.140350         0.075382            1.862           0.063
# L2.CDT 1/                             -0.089739         0.059218           -1.515           0.130
# L2.Otros depósitos a la vista         -0.004562         0.113004           -0.040           0.968
# L2.Cuentas de ahorro                   0.019722         0.018082            1.091           0.275
# L3.AUM FIC                             0.000684         0.000405            1.690           0.091
# L3.Efectivo                           -0.059095         0.074155           -0.797           0.425
# L3.CDT 1/                             -0.012902         0.059753           -0.216           0.829
# L3.Otros depósitos a la vista         -0.089052         0.118253           -0.753           0.451
# L3.Cuentas de ahorro                   0.040771         0.018357            2.221           0.026
# L4.AUM FIC                            -0.000119         0.000446           -0.266           0.790
# L4.Efectivo                           -0.026459         0.072624           -0.364           0.716
# L4.CDT 1/                              0.003603         0.059325            0.061           0.952
# L4.Otros depósitos a la vista          0.052946         0.117458            0.451           0.652
# L4.Cuentas de ahorro                   0.022446         0.018421            1.218           0.223
# L5.AUM FIC                            -0.000142         0.000716           -0.198           0.843
# L5.Efectivo                           -0.219173         0.072381           -3.028           0.002
# L5.CDT 1/                             -0.055997         0.058876           -0.951           0.342
# L5.Otros depósitos a la vista          0.242447         0.114419            2.119           0.034
# L5.Cuentas de ahorro                  -0.012123         0.018398           -0.659           0.510
# L6.AUM FIC                            -0.000289         0.000866           -0.333           0.739
# L6.Efectivo                           -0.110049         0.073442           -1.498           0.134
# L6.CDT 1/                             -0.015377         0.059092           -0.260           0.795
# L6.Otros depósitos a la vista          0.111778         0.115589            0.967           0.334
# L6.Cuentas de ahorro                  -0.021137         0.018198           -1.161           0.245
# L7.AUM FIC                            -0.001033         0.000963           -1.073           0.283
# L7.Efectivo                           -0.051545         0.072564           -0.710           0.477
# L7.CDT 1/                             -0.023941         0.059976           -0.399           0.690
# L7.Otros depósitos a la vista         -0.047471         0.117198           -0.405           0.685
# L7.Cuentas de ahorro                   0.017238         0.018203            0.947           0.344
# L8.AUM FIC                             0.000860         0.001034            0.831           0.406
# L8.Efectivo                            0.099215         0.073483            1.350           0.177
# L8.CDT 1/                              0.070778         0.060579            1.168           0.243
# L8.Otros depósitos a la vista         -0.284500         0.120623           -2.359           0.018
# L8.Cuentas de ahorro                   0.025962         0.018809            1.380           0.167
# L9.AUM FIC                            -0.000271         0.001057           -0.257           0.797
# L9.Efectivo                            0.223453         0.073633            3.035           0.002
# L9.CDT 1/                              0.061566         0.059310            1.038           0.299
# L9.Otros depósitos a la vista         -0.032533         0.122089           -0.266           0.790
# L9.Cuentas de ahorro                   0.041571         0.018741            2.218           0.027
# L10.AUM FIC                           -0.002222         0.001072           -2.073           0.038
# L10.Efectivo                          -0.179843         0.075090           -2.395           0.017
# L10.CDT 1/                            -0.063150         0.058162           -1.086           0.278
# L10.Otros depósitos a la vista        -0.095381         0.122634           -0.778           0.437
# L10.Cuentas de ahorro                  0.014683         0.018673            0.786           0.432
# L11.AUM FIC                            0.000891         0.001106            0.805           0.421
# L11.Efectivo                          -0.045427         0.075905           -0.598           0.550
# L11.CDT 1/                            -0.027845         0.058537           -0.476           0.634
# L11.Otros depósitos a la vista        -0.012947         0.118715           -0.109           0.913
# L11.Cuentas de ahorro                 -0.030590         0.017990           -1.700           0.089
# L12.AUM FIC                            0.000817         0.001073            0.761           0.446
# L12.Efectivo                          -0.119705         0.074345           -1.610           0.107
# L12.CDT 1/                            -0.004036         0.059449           -0.068           0.946
# L12.Otros depósitos a la vista        -0.075031         0.113555           -0.661           0.509
# L12.Cuentas de ahorro                 -0.007087         0.017913           -0.396           0.692
# L13.AUM FIC                           -0.000934         0.001013           -0.922           0.356
# L13.Efectivo                           0.266182         0.072830            3.655           0.000
# L13.CDT 1/                            -0.002998         0.058273           -0.051           0.959
# L13.Otros depósitos a la vista         0.068256         0.105707            0.646           0.518
# L13.Cuentas de ahorro                  0.000147         0.018305            0.008           0.994
# L14.AUM FIC                            0.000051         0.000926            0.055           0.956
# L14.Efectivo                          -0.175898         0.072665           -2.421           0.015
# L14.CDT 1/                             0.005229         0.057373            0.091           0.927
# L14.Otros depósitos a la vista         0.027993         0.094132            0.297           0.766
# L14.Cuentas de ahorro                  0.015489         0.018180            0.852           0.394
# L15.AUM FIC                            0.000227         0.000732            0.310           0.756
# L15.Efectivo                          -0.083050         0.066637           -1.246           0.213
# L15.CDT 1/                             0.028624         0.053213            0.538           0.591
# L15.Otros depósitos a la vista        -0.016254         0.082209           -0.198           0.843
# L15.Cuentas de ahorro                  0.023350         0.018383            1.270           0.204
# =================================================================================================
#
# Results for equation CDT 1/
# =================================================================================================
#                                     coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------
# const                               -124.450164        79.508148           -1.565           0.118
# L1.AUM FIC                             0.000835         0.000466            1.791           0.073
# L1.Efectivo                           -0.083507         0.085283           -0.979           0.327
# L1.CDT 1/                              0.358942         0.065982            5.440           0.000
# L1.Otros depósitos a la vista         -0.128436         0.112891           -1.138           0.255
# L1.Cuentas de ahorro                  -0.016457         0.020924           -0.787           0.432
# L2.AUM FIC                            -0.000144         0.000481           -0.300           0.764
# L2.Efectivo                            0.097140         0.089710            1.083           0.279
# L2.CDT 1/                              0.150740         0.070473            2.139           0.032
# L2.Otros depósitos a la vista         -0.160260         0.134483           -1.192           0.233
# L2.Cuentas de ahorro                   0.023187         0.021519            1.078           0.281
# L3.AUM FIC                            -0.001019         0.000482           -2.116           0.034
# L3.Efectivo                           -0.032390         0.088250           -0.367           0.714
# L3.CDT 1/                              0.240716         0.071110            3.385           0.001
# L3.Otros depósitos a la vista          0.082483         0.140731            0.586           0.558
# L3.Cuentas de ahorro                   0.046936         0.021846            2.149           0.032
# L4.AUM FIC                             0.000657         0.000531            1.237           0.216
# L4.Efectivo                            0.002851         0.086429            0.033           0.974
# L4.CDT 1/                              0.041299         0.070601            0.585           0.559
# L4.Otros depósitos a la vista         -0.062715         0.139783           -0.449           0.654
# L4.Cuentas de ahorro                   0.013661         0.021923            0.623           0.533
# L5.AUM FIC                            -0.001023         0.000852           -1.201           0.230
# L5.Efectivo                            0.128126         0.086138            1.487           0.137
# L5.CDT 1/                              0.106840         0.070067            1.525           0.127
# L5.Otros depósitos a la vista         -0.057894         0.136167           -0.425           0.671
# L5.Cuentas de ahorro                   0.009745         0.021895            0.445           0.656
# L6.AUM FIC                             0.001928         0.001031            1.871           0.061
# L6.Efectivo                           -0.018086         0.087402           -0.207           0.836
# L6.CDT 1/                             -0.015945         0.070324           -0.227           0.821
# L6.Otros depósitos a la vista          0.104381         0.137560            0.759           0.448
# L6.Cuentas de ahorro                   0.031503         0.021657            1.455           0.146
# L7.AUM FIC                            -0.000052         0.001146           -0.045           0.964
# L7.Efectivo                           -0.218262         0.086357           -2.527           0.011
# L7.CDT 1/                              0.123194         0.071376            1.726           0.084
# L7.Otros depósitos a la vista          0.314703         0.139475            2.256           0.024
# L7.Cuentas de ahorro                   0.026398         0.021663            1.219           0.223
# L8.AUM FIC                             0.000237         0.001231            0.193           0.847
# L8.Efectivo                            0.106690         0.087450            1.220           0.222
# L8.CDT 1/                             -0.056821         0.072094           -0.788           0.431
# L8.Otros depósitos a la vista          0.258217         0.143551            1.799           0.072
# L8.Cuentas de ahorro                   0.030943         0.022384            1.382           0.167
# L9.AUM FIC                            -0.000397         0.001258           -0.315           0.752
# L9.Efectivo                            0.169368         0.087629            1.933           0.053
# L9.CDT 1/                             -0.020244         0.070583           -0.287           0.774
# L9.Otros depósitos a la vista          0.127653         0.145296            0.879           0.380
# L9.Cuentas de ahorro                  -0.011692         0.022303           -0.524           0.600
# L10.AUM FIC                            0.001073         0.001276            0.841           0.400
# L10.Efectivo                          -0.056174         0.089363           -0.629           0.530
# L10.CDT 1/                            -0.175435         0.069218           -2.535           0.011
# L10.Otros depósitos a la vista         0.175761         0.145943            1.204           0.228
# L10.Cuentas de ahorro                 -0.030389         0.022222           -1.368           0.171
# L11.AUM FIC                           -0.000687         0.001316           -0.522           0.602
# L11.Efectivo                          -0.000317         0.090333           -0.004           0.997
# L11.CDT 1/                            -0.127571         0.069663           -1.831           0.067
# L11.Otros depósitos a la vista         0.073841         0.141279            0.523           0.601
# L11.Cuentas de ahorro                  0.015618         0.021410            0.730           0.466
# L12.AUM FIC                           -0.001210         0.001277           -0.947           0.344
# L12.Efectivo                           0.026771         0.088476            0.303           0.762
# L12.CDT 1/                             0.142321         0.070749            2.012           0.044
# L12.Otros depósitos a la vista         0.127920         0.135139            0.947           0.344
# L12.Cuentas de ahorro                 -0.059850         0.021318           -2.807           0.005
# L13.AUM FIC                           -0.000058         0.001206           -0.048           0.962
# L13.Efectivo                           0.101031         0.086673            1.166           0.244
# L13.CDT 1/                             0.075537         0.069349            1.089           0.276
# L13.Otros depósitos a la vista        -0.083340         0.125799           -0.662           0.508
# L13.Cuentas de ahorro                  0.029991         0.021784            1.377           0.169
# L14.AUM FIC                            0.000765         0.001102            0.694           0.488
# L14.Efectivo                           0.051490         0.086477            0.595           0.552
# L14.CDT 1/                             0.146454         0.068279            2.145           0.032
# L14.Otros depósitos a la vista        -0.235936         0.112025           -2.106           0.035
# L14.Cuentas de ahorro                  0.032155         0.021635            1.486           0.137
# L15.AUM FIC                            0.000816         0.000871            0.936           0.349
# L15.Efectivo                          -0.044974         0.079304           -0.567           0.571
# L15.CDT 1/                             0.025452         0.063328            0.402           0.688
# L15.Otros depósitos a la vista        -0.213121         0.097835           -2.178           0.029
# L15.Cuentas de ahorro                  0.018227         0.021877            0.833           0.405
# =================================================================================================
#
# Results for equation Otros depósitos a la vista
# =================================================================================================
#                                     coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------
# const                                 23.281362        48.809087            0.477           0.633
# L1.AUM FIC                             0.000290         0.000286            1.012           0.312
# L1.Efectivo                            0.264446         0.052354            5.051           0.000
# L1.CDT 1/                              0.081018         0.040505            2.000           0.045
# L1.Otros depósitos a la vista         -0.612654         0.069303           -8.840           0.000
# L1.Cuentas de ahorro                   0.007331         0.012845            0.571           0.568
# L2.AUM FIC                            -0.000106         0.000295           -0.358           0.721
# L2.Efectivo                            0.128273         0.055072            2.329           0.020
# L2.CDT 1/                             -0.027750         0.043263           -0.641           0.521
# L2.Otros depósitos a la vista         -0.432671         0.082557           -5.241           0.000
# L2.Cuentas de ahorro                   0.019500         0.013210            1.476           0.140
# L3.AUM FIC                            -0.000842         0.000296           -2.850           0.004
# L3.Efectivo                           -0.021823         0.054176           -0.403           0.687
# L3.CDT 1/                             -0.058766         0.043654           -1.346           0.178
# L3.Otros depósitos a la vista         -0.295460         0.086393           -3.420           0.001
# L3.Cuentas de ahorro                   0.014315         0.013411            1.067           0.286
# L4.AUM FIC                            -0.000307         0.000326           -0.941           0.347
# L4.Efectivo                            0.047711         0.053057            0.899           0.369
# L4.CDT 1/                              0.000467         0.043341            0.011           0.991
# L4.Otros depósitos a la vista         -0.109204         0.085811           -1.273           0.203
# L4.Cuentas de ahorro                  -0.004330         0.013458           -0.322           0.748
# L5.AUM FIC                             0.000529         0.000523            1.013           0.311
# L5.Efectivo                           -0.167113         0.052879           -3.160           0.002
# L5.CDT 1/                             -0.059322         0.043013           -1.379           0.168
# L5.Otros depósitos a la vista          0.004623         0.083592            0.055           0.956
# L5.Cuentas de ahorro                  -0.008611         0.013441           -0.641           0.522
# L6.AUM FIC                            -0.000799         0.000633           -1.263           0.207
# L6.Efectivo                           -0.077075         0.053655           -1.437           0.151
# L6.CDT 1/                             -0.028051         0.043171           -0.650           0.516
# L6.Otros depósitos a la vista         -0.036374         0.084446           -0.431           0.667
# L6.Cuentas de ahorro                  -0.016138         0.013295           -1.214           0.225
# L7.AUM FIC                             0.001031         0.000703            1.466           0.143
# L7.Efectivo                           -0.038680         0.053013           -0.730           0.466
# L7.CDT 1/                              0.073418         0.043817            1.676           0.094
# L7.Otros depósitos a la vista         -0.213207         0.085622           -2.490           0.013
# L7.Cuentas de ahorro                  -0.024779         0.013299           -1.863           0.062
# L8.AUM FIC                            -0.000447         0.000755           -0.592           0.554
# L8.Efectivo                            0.177622         0.053685            3.309           0.001
# L8.CDT 1/                              0.039866         0.044257            0.901           0.368
# L8.Otros depósitos a la vista         -0.237907         0.088124           -2.700           0.007
# L8.Cuentas de ahorro                   0.018055         0.013741            1.314           0.189
# L9.AUM FIC                             0.001476         0.000772            1.911           0.056
# L9.Efectivo                            0.033149         0.053794            0.616           0.538
# L9.CDT 1/                              0.019406         0.043330            0.448           0.654
# L9.Otros depósitos a la vista         -0.150329         0.089195           -1.685           0.092
# L9.Cuentas de ahorro                   0.024109         0.013692            1.761           0.078
# L10.AUM FIC                           -0.003226         0.000783           -4.119           0.000
# L10.Efectivo                          -0.077323         0.054859           -1.410           0.159
# L10.CDT 1/                            -0.001802         0.042492           -0.042           0.966
# L10.Otros depósitos a la vista        -0.009653         0.089593           -0.108           0.914
# L10.Cuentas de ahorro                  0.004414         0.013642            0.324           0.746
# L11.AUM FIC                            0.000619         0.000808            0.767           0.443
# L11.Efectivo                           0.009818         0.055454            0.177           0.859
# L11.CDT 1/                             0.005468         0.042765            0.128           0.898
# L11.Otros depósitos a la vista         0.027371         0.086730            0.316           0.752
# L11.Cuentas de ahorro                 -0.013212         0.013143           -1.005           0.315
# L12.AUM FIC                            0.000885         0.000784            1.129           0.259
# L12.Efectivo                          -0.094717         0.054314           -1.744           0.081
# L12.CDT 1/                            -0.026058         0.043432           -0.600           0.549
# L12.Otros depósitos a la vista         0.116513         0.082960            1.404           0.160
# L12.Cuentas de ahorro                 -0.019062         0.013087           -1.457           0.145
# L13.AUM FIC                           -0.000106         0.000740           -0.143           0.887
# L13.Efectivo                           0.080611         0.053208            1.515           0.130
# L13.CDT 1/                            -0.057321         0.042573           -1.346           0.178
# L13.Otros depósitos a la vista         0.221095         0.077227            2.863           0.004
# L13.Cuentas de ahorro                 -0.015007         0.013373           -1.122           0.262
# L14.AUM FIC                            0.000776         0.000676            1.148           0.251
# L14.Efectivo                          -0.094896         0.053087           -1.788           0.074
# L14.CDT 1/                             0.003687         0.041916            0.088           0.930
# L14.Otros depósitos a la vista         0.050880         0.068771            0.740           0.459
# L14.Cuentas de ahorro                 -0.026841         0.013282           -2.021           0.043
# L15.AUM FIC                            0.000436         0.000535            0.815           0.415
# L15.Efectivo                           0.065420         0.048683            1.344           0.179
# L15.CDT 1/                             0.029316         0.038876            0.754           0.451
# L15.Otros depósitos a la vista         0.008715         0.060060            0.145           0.885
# L15.Cuentas de ahorro                 -0.013566         0.013430           -1.010           0.312
# =================================================================================================
#
# Results for equation Cuentas de ahorro
# =================================================================================================
#                                     coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------
# const                               1047.558628       258.727983            4.049           0.000
# L1.AUM FIC                            -0.000241         0.001517           -0.159           0.874
# L1.Efectivo                            0.206232         0.277521            0.743           0.457
# L1.CDT 1/                             -0.184429         0.214712           -0.859           0.390
# L1.Otros depósitos a la vista         -0.580008         0.367361           -1.579           0.114
# L1.Cuentas de ahorro                  -0.020372         0.068090           -0.299           0.765
# L2.AUM FIC                             0.000629         0.001565            0.402           0.688
# L2.Efectivo                            0.047294         0.291925            0.162           0.871
# L2.CDT 1/                              0.030630         0.229328            0.134           0.894
# L2.Otros depósitos a la vista         -0.212796         0.437622           -0.486           0.627
# L2.Cuentas de ahorro                   0.027560         0.070024            0.394           0.694
# L3.AUM FIC                             0.001545         0.001567            0.986           0.324
# L3.Efectivo                            0.009239         0.287176            0.032           0.974
# L3.CDT 1/                              0.056092         0.231400            0.242           0.808
# L3.Otros depósitos a la vista         -0.322921         0.457952           -0.705           0.481
# L3.Cuentas de ahorro                  -0.005800         0.071089           -0.082           0.935
# L4.AUM FIC                            -0.000145         0.001728           -0.084           0.933
# L4.Efectivo                            0.141071         0.281248            0.502           0.616
# L4.CDT 1/                              0.175250         0.229742            0.763           0.446
# L4.Otros depósitos a la vista         -0.215728         0.454870           -0.474           0.635
# L4.Cuentas de ahorro                   0.091720         0.071339            1.286           0.199
# L5.AUM FIC                             0.000328         0.002771            0.118           0.906
# L5.Efectivo                           -0.242202         0.280304           -0.864           0.388
# L5.CDT 1/                             -0.599781         0.228005           -2.631           0.009
# L5.Otros depósitos a la vista         -0.130619         0.443103           -0.295           0.768
# L5.Cuentas de ahorro                  -0.061297         0.071249           -0.860           0.390
# L6.AUM FIC                             0.000152         0.003354            0.045           0.964
# L6.Efectivo                           -0.313120         0.284415           -1.101           0.271
# L6.CDT 1/                             -0.248325         0.228842           -1.085           0.278
# L6.Otros depósitos a la vista          0.264204         0.447633            0.590           0.555
# L6.Cuentas de ahorro                  -0.119836         0.070475           -1.700           0.089
# L7.AUM FIC                            -0.007732         0.003728           -2.074           0.038
# L7.Efectivo                           -0.602347         0.281014           -2.143           0.032
# L7.CDT 1/                              0.133189         0.232265            0.573           0.566
# L7.Otros depósitos a la vista          0.050961         0.453867            0.112           0.911
# L7.Cuentas de ahorro                  -0.057199         0.070495           -0.811           0.417
# L8.AUM FIC                             0.004665         0.004005            1.165           0.244
# L8.Efectivo                            0.195975         0.284572            0.689           0.491
# L8.CDT 1/                              0.154211         0.234600            0.657           0.511
# L8.Otros depósitos a la vista         -0.061580         0.467130           -0.132           0.895
# L8.Cuentas de ahorro                  -0.046013         0.072839           -0.632           0.528
# L9.AUM FIC                            -0.007087         0.004094           -1.731           0.083
# L9.Efectivo                            0.051360         0.285154            0.180           0.857
# L9.CDT 1/                              0.159411         0.229686            0.694           0.488
# L9.Otros depósitos a la vista          0.974036         0.472807            2.060           0.039
# L9.Cuentas de ahorro                   0.125674         0.072576            1.732           0.083
# L10.AUM FIC                            0.008988         0.004151            2.165           0.030
# L10.Efectivo                          -0.378944         0.290796           -1.303           0.193
# L10.CDT 1/                             0.026503         0.225241            0.118           0.906
# L10.Otros depósitos a la vista         0.763738         0.474915            1.608           0.108
# L10.Cuentas de ahorro                 -0.003903         0.072313           -0.054           0.957
# L11.AUM FIC                           -0.003850         0.004282           -0.899           0.369
# L11.Efectivo                          -0.329685         0.293952           -1.122           0.262
# L11.CDT 1/                            -0.348728         0.226692           -1.538           0.124
# L11.Otros depósitos a la vista         0.037492         0.459738            0.082           0.935
# L11.Cuentas de ahorro                 -0.064617         0.069669           -0.927           0.354
# L12.AUM FIC                            0.008924         0.004157            2.147           0.032
# L12.Efectivo                           0.160719         0.287910            0.558           0.577
# L12.CDT 1/                             0.181781         0.230225            0.790           0.430
# L12.Otros depósitos a la vista        -0.212647         0.439756           -0.484           0.629
# L12.Cuentas de ahorro                 -0.112847         0.069372           -1.627           0.104
# L13.AUM FIC                           -0.002307         0.003923           -0.588           0.557
# L13.Efectivo                          -0.160592         0.282043           -0.569           0.569
# L13.CDT 1/                            -0.272015         0.225670           -1.205           0.228
# L13.Otros depósitos a la vista         0.455165         0.409365            1.112           0.266
# L13.Cuentas de ahorro                 -0.040049         0.070887           -0.565           0.572
# L14.AUM FIC                            0.000514         0.003585            0.143           0.886
# L14.Efectivo                           0.169933         0.281405            0.604           0.546
# L14.CDT 1/                            -0.160416         0.222186           -0.722           0.470
# L14.Otros depósitos a la vista         0.379031         0.364540            1.040           0.298
# L14.Cuentas de ahorro                 -0.029306         0.070403           -0.416           0.677
# L15.AUM FIC                           -0.004793         0.002835           -1.691           0.091
# L15.Efectivo                           0.291351         0.258062            1.129           0.259
# L15.CDT 1/                             0.004858         0.206075            0.024           0.981
# L15.Otros depósitos a la vista        -0.241472         0.318365           -0.758           0.448
# L15.Cuentas de ahorro                 -0.068273         0.071190           -0.959           0.338
# =================================================================================================
#
# Correlation matrix of residuals
#                                AUM FIC  Efectivo    CDT 1/  Otros depósitos a la vista  Cuentas de ahorro
# AUM FIC                       1.000000  0.031802 -0.035395                   -0.004012          -0.116508
# Efectivo                      0.031802  1.000000  0.086968                    0.380122           0.238422
# CDT 1/                       -0.035395  0.086968  1.000000                    0.011141          -0.191901
# Otros depósitos a la vista   -0.004012  0.380122  0.011141                    1.000000           0.012210
# Cuentas de ahorro            -0.116508  0.238422 -0.191901                    0.012210           1.000000

# %% [markdown]
# AUM FIC

# %%
grangercaus = resultados_var_3.test_causality(['Efectivo','CDT 1/','Otros depósitos a la vista','Cuentas de ahorro'
       ],['AUM FIC'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Efectivo

# %%
grangercaus = resultados_var_3.test_causality(['AUM FIC','CDT 1/','Otros depósitos a la vista','Cuentas de ahorro'],['Efectivo'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# CDT

# %%
grangercaus = resultados_var_3.test_causality(['AUM FIC','Efectivo','Otros depósitos a la vista','Cuentas de ahorro'],['CDT 1/'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Otros Depositos a la vista

# %%
grangercaus = resultados_var_3.test_causality(['AUM FIC','Efectivo','CDT 1/','Cuentas de ahorro'],['Otros depósitos a la vista'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### Residuos

# %%
residuos3 = resultados_var_3.resid

# %%
# Gráfico de los residuos
fig, axs = plt.subplots(5)

fig.suptitle('Gráficos de los residuos', fontsize = 20)

fig.set_size_inches(18,10)

[axs[i].plot(residuos3.iloc[:,i]) for i in range(5)]

plt.show()

# %% [markdown]
# Dickey Fuller a los residuos

# %%
[sts.adfuller(residuos3.iloc[:,i])[1] for i in range(5)]
# Out:
# [4.963034637299037e-30,
#  3.092984429170018e-30,
#  3.036121774195278e-30,
#  4.2928237078325285e-30,
#  3.46609014967302e-30]

# %% [markdown]
# Residuos estacionarios

# %% [markdown]
# ### Valores Predichos

# %%
y_fitted_3 = resultados_var_3.fittedvalues

fig , axs = plt.subplots(5)

fig.suptitle ('Gráficos de los valores predichos por el modelo',fontsize = 20)

fig.set_size_inches(18,10)

[axs[i].plot(y_fitted_3.iloc[:,i]) for i in range (5)]

plt.show()

# %%
lag_order_3 = resultados_var_3.k_ar

input_data_3 = train3.values[-lag_order_3:]

# Forecasting

pred_3 = resultados_var_3.forecast(y=input_data_3,steps=n_obs)

pred_3 = (pd.DataFrame(pred_3,index=test3[-n_obs:].index, columns= test3.columns + '_pred'))

print('Predicciones')

pred_3
# Out:
# Predicciones
#              AUM FIC_pred  Efectivo_pred  CDT 1/_pred  \
# Fecha
# 2024-05-18    9622.171075    -277.768685  1695.883009
# 2024-05-25   54540.467419    2199.838838  -648.768652
# 2024-06-01   34087.424394    2145.459527  -207.027566
# 2024-06-08  173804.238259    -478.131842  -315.419971
# 2024-06-15  192544.914149     -55.769788   635.125941
# 2024-06-22   27567.917540    4680.715380 -1321.500423
# 2024-06-29   78124.445794     844.285023   330.905030
#
#             Otros depósitos a la vista_pred  Cuentas de ahorro_pred
# Fecha
# 2024-05-18                      -931.485590            -1973.603064
# 2024-05-25                      2808.105463             5525.368340
# 2024-06-01                     -2978.932983            10867.533456
# 2024-06-08                      2114.992961            -7393.814315
# 2024-06-15                     -2599.207312             7736.354473
# 2024-06-22                      6590.664117            -9005.116261
# 2024-06-29                     -3162.641344             7609.052545

# %%
# Traer el dataset original

lista_3 = serie_dif_3.index

serie_filtrada_3 = serie3.loc[lista_3]

serie_filtrada_3
# Out:
#                  AUM FIC       Efectivo         CDT 1/  \
# Fecha
# 2018-01-06  4.464748e+07   56599.538551  160158.814562
# 2018-01-13  4.472463e+07   55441.177763  161336.306592
# 2018-01-20  4.419130e+07   54230.235116  162535.157785
# 2018-01-27  4.425412e+07   55369.850529  163018.106472
# 2018-02-03  4.510664e+07   54356.195805  163739.925042
# ...                  ...            ...            ...
# 2024-06-01  7.587088e+07  108830.824490  305755.773893
# 2024-06-08  7.707061e+07  108510.181501  305537.795854
# 2024-06-15  7.657252e+07  108635.505529  306954.550771
# 2024-06-22  7.708270e+07  110703.789150  308807.308420
# 2024-06-29  7.533655e+07  113349.537115  308954.440917
#
#             Otros depósitos a la vista  Cuentas de ahorro
# Fecha
# 2018-01-06                 4524.240271      169252.278075
# 2018-01-13                 4684.230184      166869.811770
# 2018-01-20                 4379.362195      162781.465049
# 2018-01-27                 5042.545758      165718.568266
# 2018-02-03                 4584.129743      163566.033986
# ...                                ...                ...
# 2024-06-01                10301.086517      294865.576409
# 2024-06-08                10851.248876      293965.059665
# 2024-06-15                10432.714266      290520.880903
# 2024-06-22                11750.407298      300428.132405
# 2024-06-29                11117.476384      298898.800990
#
# [339 rows x 5 columns]

# %%
output_3 = invert_transformation(serie_filtrada_3[-n_obs:],pred_3)

output_3
# Out:
#             AUM FIC_pred  Efectivo_pred    CDT 1/_pred  \
# Fecha
# 2024-05-18  7.534617e+07  113071.768430  310650.323926
# 2024-05-25  7.540071e+07  115271.607268  310001.555275
# 2024-06-01  7.543480e+07  117417.066795  309794.527708
# 2024-06-08  7.560860e+07  116938.934953  309479.107737
# 2024-06-15  7.580114e+07  116883.165165  310114.233678
# 2024-06-22  7.582871e+07  121563.880545  308792.733255
# 2024-06-29  7.590684e+07  122408.165568  309123.638286
#
#             Otros depósitos a la vista_pred  Cuentas de ahorro_pred
# Fecha
# 2024-05-18                     10185.990794           296925.197926
# 2024-05-25                     12994.096257           302450.566266
# 2024-06-01                     10015.163275           313318.099722
# 2024-06-08                     12130.156236           305924.285408
# 2024-06-15                      9530.948924           313660.639881
# 2024-06-22                     16121.613041           304655.523620
# 2024-06-29                     12958.971697           312264.576166

# %%
plt.rcParams['figure.figsize'] = (20,8)

sns.lineplot(output_3, x= output_3.index, y=output_3['AUM FIC_pred'],label = 'AUM FIC Forecast')

sns.lineplot(serie_filtrada_3[-n_obs:], x= serie_filtrada_3[-n_obs:].index, y=serie_filtrada_3['AUM FIC'][-n_obs:],label = 'AUM FIC')

plt.show()

# %% [markdown]
# ### Evaluación del modelo

# %%
metricas_var_3 = calculate_metrics(serie_filtrada_3['AUM FIC'].tail(n_obs),output_3['AUM FIC_pred'])

metricas_var_3
# Out:
# (4153713797224.427, 2038066.1905896056, 1633590.3970283654, 2.094937516032349)

# %%
# Comparar resultados
resultados = pd.DataFrame({
    'Model': ['VAR1', 'VAR2'],
    'MSE': [metricas_var_2[0],metricas_var_3[0]],
    'RMSE': [metricas_var_2[1],metricas_var_3[1]],
    'MAE': [metricas_var_2[2],metricas_var_3[2]],
    'MAPE': [metricas_var_2[3],metricas_var_3[3]]
})

resultados
# Out:
#   Model           MSE          RMSE           MAE      MAPE
# 0  VAR1  4.687991e+12  2.165177e+06  1.764271e+06  2.262732
# 1  VAR2  4.153714e+12  2.038066e+06  1.633590e+06  2.094938

# %% [markdown]
# ## VAR 4 - CDT y Efectivo

# %% [markdown]
# ### Transformar los datos

# %%
serie4 = df[['AUM FIC','CDT 1/','Efectivo']]

serie_dif_4 = serie4.diff().dropna()

serie_dif_4 = serie_dif_4[(serie_dif_4 != 0).all(axis=1)]

serie_dif_4
# Out:
#                  AUM FIC       CDT 1/     Efectivo
# Fecha
# 2018-01-06   6734.988641   -67.310789 -1912.465334
# 2018-01-13   7047.624598  1177.492029 -1158.360789
# 2018-01-20   6779.730104  1198.851193 -1210.942647
# 2018-01-27   8954.972046   482.948687  1139.615413
# 2018-02-03   6038.756100   721.818570 -1013.654724
# ...                  ...          ...          ...
# 2024-06-01  22557.398097    13.080693  1160.292575
# 2024-06-08  21575.713932  -217.978039  -320.642989
# 2024-06-15  20545.053360  1416.754917   125.324028
# 2024-06-22  17301.417742  1852.757649  2068.283621
# 2024-06-29  24667.715961   147.132497  2645.747965
#
# [339 rows x 3 columns]

# %% [markdown]
# ### Conjunto de entrenamiento y conjunto de prueba

# %%
train4 = serie_dif_4.iloc[:332]

test4 = serie_dif_4.iloc[332:]

print(train4.shape)

print(test4.shape)
# Out:
# (332, 3)
# (7, 3)

# %% [markdown]
# ### Modelo VAR

# %%
model_var_4 = VAR(train4)

resultados_var_4 = model_var_4.select_order()

resultados_var_4.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
resultados_var_4.selected_orders
# Out:
# {'aic': 14, 'bic': 6, 'hqic': 14, 'fpe': 14}

# %%
resultados_var_4 = model_var_4.fit(maxlags=14, ic= 'aic',method='ols')

display(resultados_var_4.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 28, Nov, 2024
# Time:                     21:49:13
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    51.4497
# Nobs:                     318.000    HQIC:                   50.5331
# Log likelihood:          -9162.51    FPE:                4.82716e+21
# AIC:                      49.9235    Det(Omega_mle):     3.29953e+21
# --------------------------------------------------------------------
# Results for equation AUM FIC
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const            -5293.450623      9623.392567           -0.550           0.582
# L1.AUM FIC           0.274048         0.060171            4.554           0.000
# L1.CDT 1/           15.930047         8.207330            1.941           0.052
# L1.Efectivo         -2.281446         9.316874           -0.245           0.807
# L2.AUM FIC          -0.069490         0.062581           -1.110           0.267
# L2.CDT 1/           13.208417         8.892415            1.485           0.137
# L2.Efectivo         17.948428         9.287361            1.933           0.053
# L3.AUM FIC          -0.010749         0.063085           -0.170           0.865
# L3.CDT 1/           -5.757166         8.954282           -0.643           0.520
# L3.Efectivo         -6.800681         9.304776           -0.731           0.465
# L4.AUM FIC           0.016909         0.069144            0.245           0.807
# L4.CDT 1/           -8.818235         9.058241           -0.974           0.330
# L4.Efectivo         -2.350644         9.255347           -0.254           0.800
# L5.AUM FIC          -0.041150         0.115005           -0.358           0.720
# L5.CDT 1/           10.986172         9.101975            1.207           0.227
# L5.Efectivo          6.211128         8.731519            0.711           0.477
# L6.AUM FIC           0.035158         0.139773            0.252           0.801
# L6.CDT 1/          -23.415019         9.140665           -2.562           0.010
# L6.Efectivo         -4.782229         8.476874           -0.564           0.573
# L7.AUM FIC          -0.084337         0.153965           -0.548           0.584
# L7.CDT 1/           -3.577257         9.150334           -0.391           0.696
# L7.Efectivo         -2.516062         8.547537           -0.294           0.768
# L8.AUM FIC           0.007355         0.163009            0.045           0.964
# L8.CDT 1/            7.334472         9.130670            0.803           0.422
# L8.Efectivo          8.159083         8.462458            0.964           0.335
# L9.AUM FIC          -0.131625         0.167184           -0.787           0.431
# L9.CDT 1/           12.368541         9.034639            1.369           0.171
# L9.Efectivo          7.519789         8.459379            0.889           0.374
# L10.AUM FIC          0.074718         0.167444            0.446           0.655
# L10.CDT 1/          10.965372         9.021470            1.215           0.224
# L10.Efectivo        -3.011469         8.816765           -0.342           0.733
# L11.AUM FIC         -0.029887         0.165170           -0.181           0.856
# L11.CDT 1/          -4.739886         9.051842           -0.524           0.601
# L11.Efectivo       -13.625526         9.208385           -1.480           0.139
# L12.AUM FIC          0.063934         0.155224            0.412           0.680
# L12.CDT 1/          -8.336896         8.988971           -0.927           0.354
# L12.Efectivo        19.622652         9.079329            2.161           0.031
# L13.AUM FIC         -0.010777         0.136479           -0.079           0.937
# L13.CDT 1/           9.585505         8.940834            1.072           0.284
# L13.Efectivo        -3.977756         9.110233           -0.437           0.662
# L14.AUM FIC         -0.002033         0.103470           -0.020           0.984
# L14.CDT 1/         -16.755056         8.254828           -2.030           0.042
# L14.Efectivo         0.555869         8.968223            0.062           0.951
# ===============================================================================
#
# Results for equation CDT 1/
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const              -61.099685        69.610919           -0.878           0.380
# L1.AUM FIC           0.000345         0.000435            0.792           0.428
# L1.CDT 1/            0.382564         0.059368            6.444           0.000
# L1.Efectivo         -0.063212         0.067394           -0.938           0.348
# L2.AUM FIC          -0.000244         0.000453           -0.538           0.590
# L2.CDT 1/            0.107170         0.064323            1.666           0.096
# L2.Efectivo          0.055116         0.067180            0.820           0.412
# L3.AUM FIC          -0.001210         0.000456           -2.652           0.008
# L3.CDT 1/            0.217550         0.064771            3.359           0.001
# L3.Efectivo          0.039757         0.067306            0.591           0.555
# L4.AUM FIC           0.000580         0.000500            1.161           0.246
# L4.CDT 1/            0.054927         0.065523            0.838           0.402
# L4.Efectivo         -0.017098         0.066949           -0.255           0.798
# L5.AUM FIC          -0.000648         0.000832           -0.779           0.436
# L5.CDT 1/            0.105407         0.065839            1.601           0.109
# L5.Efectivo          0.184258         0.063160            2.917           0.004
# L6.AUM FIC           0.001100         0.001011            1.088           0.277
# L6.CDT 1/           -0.061912         0.066119           -0.936           0.349
# L6.Efectivo          0.078800         0.061318            1.285           0.199
# L7.AUM FIC           0.000202         0.001114            0.181           0.856
# L7.CDT 1/            0.089319         0.066189            1.349           0.177
# L7.Efectivo         -0.061009         0.061829           -0.987           0.324
# L8.AUM FIC           0.000628         0.001179            0.533           0.594
# L8.CDT 1/           -0.054647         0.066047           -0.827           0.408
# L8.Efectivo          0.091736         0.061213            1.499           0.134
# L9.AUM FIC          -0.000699         0.001209           -0.578           0.563
# L9.CDT 1/            0.050203         0.065352            0.768           0.442
# L9.Efectivo          0.086376         0.061191            1.412           0.158
# L10.AUM FIC          0.000863         0.001211            0.712           0.476
# L10.CDT 1/          -0.114140         0.065257           -1.749           0.080
# L10.Efectivo         0.010072         0.063776            0.158           0.875
# L11.AUM FIC         -0.000962         0.001195           -0.805           0.421
# L11.CDT 1/          -0.126800         0.065477           -1.937           0.053
# L11.Efectivo         0.083899         0.066609            1.260           0.208
# L12.AUM FIC         -0.000259         0.001123           -0.231           0.817
# L12.CDT 1/           0.130685         0.065022            2.010           0.044
# L12.Efectivo        -0.001667         0.065675           -0.025           0.980
# L13.AUM FIC         -0.001047         0.000987           -1.061           0.289
# L13.CDT 1/           0.027476         0.064674            0.425           0.671
# L13.Efectivo         0.048539         0.065899            0.737           0.461
# L14.AUM FIC          0.001571         0.000748            2.099           0.036
# L14.CDT 1/           0.153916         0.059711            2.578           0.010
# L14.Efectivo        -0.109169         0.064872           -1.683           0.092
# ===============================================================================
#
# Results for equation Efectivo
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const              243.999317        59.677691            4.089           0.000
# L1.AUM FIC           0.000265         0.000373            0.711           0.477
# L1.CDT 1/            0.036751         0.050896            0.722           0.470
# L1.Efectivo          0.412566         0.057777            7.141           0.000
# L2.AUM FIC          -0.000590         0.000388           -1.521           0.128
# L2.CDT 1/           -0.099660         0.055145           -1.807           0.071
# L2.Efectivo          0.065387         0.057594            1.135           0.256
# L3.AUM FIC           0.000536         0.000391            1.370           0.171
# L3.CDT 1/           -0.032162         0.055528           -0.579           0.562
# L3.Efectivo         -0.127044         0.057702           -2.202           0.028
# L4.AUM FIC           0.000022         0.000429            0.052           0.958
# L4.CDT 1/            0.030788         0.056173            0.548           0.584
# L4.Efectivo          0.073673         0.057395            1.284           0.199
# L5.AUM FIC          -0.000070         0.000713           -0.098           0.922
# L5.CDT 1/           -0.056021         0.056444           -0.993           0.321
# L5.Efectivo         -0.103768         0.054147           -1.916           0.055
# L6.AUM FIC           0.000235         0.000867            0.271           0.787
# L6.CDT 1/            0.012929         0.056684            0.228           0.820
# L6.Efectivo         -0.102552         0.052568           -1.951           0.051
# L7.AUM FIC          -0.001461         0.000955           -1.530           0.126
# L7.CDT 1/           -0.062183         0.056744           -1.096           0.273
# L7.Efectivo         -0.095653         0.053006           -1.805           0.071
# L8.AUM FIC          -0.000008         0.001011           -0.008           0.994
# L8.CDT 1/            0.040010         0.056622            0.707           0.480
# L8.Efectivo          0.015313         0.052478            0.292           0.770
# L9.AUM FIC          -0.000009         0.001037           -0.009           0.993
# L9.CDT 1/           -0.023410         0.056027           -0.418           0.676
# L9.Efectivo          0.274364         0.052459            5.230           0.000
# L10.AUM FIC         -0.002914         0.001038           -2.806           0.005
# L10.CDT 1/          -0.042834         0.055945           -0.766           0.444
# L10.Efectivo        -0.293950         0.054676           -5.376           0.000
# L11.AUM FIC          0.002075         0.001024            2.026           0.043
# L11.CDT 1/           0.072568         0.056133            1.293           0.196
# L11.Efectivo        -0.066296         0.057104           -1.161           0.246
# L12.AUM FIC          0.000296         0.000963            0.307           0.759
# L12.CDT 1/           0.021343         0.055743            0.383           0.702
# L12.Efectivo        -0.093874         0.056304           -1.667           0.095
# L13.AUM FIC          0.000063         0.000846            0.074           0.941
# L13.CDT 1/          -0.022882         0.055445           -0.413           0.680
# L13.Efectivo         0.388395         0.056495            6.875           0.000
# L14.AUM FIC          0.000274         0.000642            0.426           0.670
# L14.CDT 1/          -0.050788         0.051191           -0.992           0.321
# L14.Efectivo        -0.280988         0.055615           -5.052           0.000
# ===============================================================================
#
# Correlation matrix of residuals
#              AUM FIC    CDT 1/  Efectivo
# AUM FIC     1.000000 -0.084606  0.005333
# CDT 1/     -0.084606  1.000000  0.036631
# Efectivo    0.005333  0.036631  1.000000

# %% [markdown]
# AUM FIC

# %%
grangercaus = resultados_var_4.test_causality(['CDT 1/','Efectivo'],['AUM FIC'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# CDT

# %%
grangercaus = resultados_var_4.test_causality(['AUM FIC','Efectivo'],['CDT 1/'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Efectivo

# %%
grangercaus = resultados_var_4.test_causality(['AUM FIC','CDT 1/'],['Efectivo'],kind = 'f')

grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### Residuos

# %%
residuos4 = resultados_var_4.resid

# %%
# Gráfico de los residuos
fig, axs = plt.subplots(3)

fig.suptitle('Gráficos de los residuos', fontsize = 20)

fig.set_size_inches(18,10)

[axs[i].plot(residuos4.iloc[:,i]) for i in range(3)]

plt.show()

# %% [markdown]
# Dickey Fuller a los residuos

# %%
[sts.adfuller(residuos4.iloc[:,i])[1] for i in range(3)]
# Out:
# [3.564329181498781e-30, 2.571591068138103e-30, 2.4883378773655626e-30]

# %% [markdown]
# ### Valores Predichos

# %%
y_fitted_4 = resultados_var_4.fittedvalues

fig , axs = plt.subplots(3)

fig.suptitle ('Gráficos de los valores predichos por el modelo',fontsize = 20)

fig.set_size_inches(18,10)

[axs[i].plot(y_fitted_4.iloc[:,i]) for i in range (3)]

plt.show()

# %%
lag_order_4 = resultados_var_4.k_ar

input_data_4 = train4.values[-lag_order_4:]

# Forecasting

pred_4 = resultados_var_4.forecast(y=input_data_4,steps=n_obs)

pred_4 = (pd.DataFrame(pred_4,index=test4[-n_obs:].index, columns= test4.columns + '_pred'))

print('Predicciones')

pred_4
# Out:
# Predicciones
#              AUM FIC_pred  CDT 1/_pred  Efectivo_pred
# Fecha
# 2024-05-18  106891.722534  1221.379164    -355.123009
# 2024-05-25  -57213.323806  -706.772622    1748.003672
# 2024-06-01   69296.772362  -348.738697    1797.857528
# 2024-06-08  -53609.584779  -565.360405     247.238549
# 2024-06-15  167836.234966   632.398105     113.776611
# 2024-06-22  -26136.014206 -1042.585706    5030.601998
# 2024-06-29  -25532.166892   678.878541     231.432537

# %%
# Traer el dataset original

lista_4 = serie_dif_4.index

serie_filtrada_4 = serie4.loc[lista_4]

serie_filtrada_4
# Out:
#                  AUM FIC         CDT 1/       Efectivo
# Fecha
# 2018-01-06  4.464748e+07  160158.814562   56599.538551
# 2018-01-13  4.472463e+07  161336.306592   55441.177763
# 2018-01-20  4.419130e+07  162535.157785   54230.235116
# 2018-01-27  4.425412e+07  163018.106472   55369.850529
# 2018-02-03  4.510664e+07  163739.925042   54356.195805
# ...                  ...            ...            ...
# 2024-06-01  7.587088e+07  305755.773893  108830.824490
# 2024-06-08  7.707061e+07  305537.795854  108510.181501
# 2024-06-15  7.657252e+07  306954.550771  108635.505529
# 2024-06-22  7.708270e+07  308807.308420  110703.789150
# 2024-06-29  7.533655e+07  308954.440917  113349.537115
#
# [339 rows x 3 columns]

# %%
output_4 = invert_transformation(serie_filtrada_4[-n_obs:],pred_4)

output_4
# Out:
#             AUM FIC_pred    CDT 1/_pred  Efectivo_pred
# Fecha
# 2024-05-18  7.544344e+07  310175.820082  112994.414106
# 2024-05-25  7.538622e+07  309469.047459  114742.417777
# 2024-06-01  7.545552e+07  309120.308762  116540.275305
# 2024-06-08  7.540191e+07  308554.948357  116787.513854
# 2024-06-15  7.556975e+07  309187.346462  116901.290465
# 2024-06-22  7.554361e+07  308144.760756  121931.892463
# 2024-06-29  7.551808e+07  308823.639297  122163.325000

# %%
plt.rcParams['figure.figsize'] = (20,8)

sns.lineplot(output_4, x= output_4.index, y=output_4['AUM FIC_pred'],label = 'AUM FIC Forecast')

sns.lineplot(serie_filtrada_4[-n_obs:], x= serie_filtrada_4[-n_obs:].index, y=serie_filtrada_4['AUM FIC'][-n_obs:],label = 'AUM FIC')

plt.show()

# %% [markdown]
# ### Evaluación del modelo

# %%
metricas_var_4 = calculate_metrics(serie_filtrada_4['AUM FIC'].tail(n_obs),output_4['AUM FIC_pred'])

metricas_var_4
# Out:
# (4284425880700.6396,
#  2069885.4752620107,
#  1666578.8364955762,
#  2.1367033138615352)

# %%
# Comparar resultados
resultados = pd.DataFrame({
    'Model': ['VAR1', 'VAR2','VAR3','ARIMA','ARIMAX'],
    'MSE': [metricas_var_2[0],metricas_var_3[0],metricas_var_4[0],metricas_arima[0],metricas_arimax[0]],
    'RMSE': [metricas_var_2[1],metricas_var_3[1],metricas_var_4[1],metricas_arima[1],metricas_arimax[1]],
    'MAE': [metricas_var_2[2],metricas_var_3[2],metricas_var_4[2],metricas_arima[2],metricas_arimax[2]],
    'MAPE': [metricas_var_2[3],metricas_var_3[3],metricas_var_4[3],metricas_arima[3],metricas_arimax[3]]
})

resultados
# Out:
#     Model           MSE          RMSE           MAE      MAPE
# 0    VAR1  4.687991e+12  2.165177e+06  1.764271e+06  2.262732
# 1    VAR2  4.153714e+12  2.038066e+06  1.633590e+06  2.094938
# 2    VAR3  4.284426e+12  2.069885e+06  1.666579e+06  2.136703
# 3   ARIMA  1.542285e+13  3.927194e+06  3.805878e+06       NaN
# 4  ARIMAX  4.658559e+12  2.158370e+06  1.752242e+06       NaN
